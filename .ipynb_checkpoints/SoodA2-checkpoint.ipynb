# %%
#Import the right package
from scipy.io import loadmat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as image
from sklearn.model_selection import train_test_split
import os
from PIL import Image, ImageOps
import imageio
# %matplotlib inline

# %%
#Load the data
metaData = loadmat("wiki_labeled.mat",squeeze_me=True, struct_as_record=True)

# %%
#Here is the entire matlab structure data

# %%
#Get the dob field from the structure data
dob = metaData['wiki_labeled']['dob'].item(0)
photo_taken = metaData['wiki_labeled']['photo_taken'].item(0)
full_path = metaData['wiki_labeled']['full_path'].item(0)
gender = metaData['wiki_labeled']['gender'].item(0)
name = metaData['wiki_labeled']['name'].item(0)
face_location = metaData['wiki_labeled']['face_location'].item(0)
face_score = metaData['wiki_labeled']['face_score'].item(0)
second_face_score = metaData['wiki_labeled']['second_face_score'].item(0)
dob_str = metaData['wiki_labeled']['dob_str'].item(0)
age = metaData['wiki_labeled']['age'].item(0)
ID = metaData['wiki_labeled']['ID'].item(0)

# %%
#See how it looks
print(photo_taken)
dob.shape
agex = age[:574]
agex.shape
# Out:
# [2009 2008 1961 ... 2013 2011 2008]
# (574,)

# %%
#It is neat, isn't it?
y = { 'age': age}
x = {'dob': dob, 'photo_taken': photo_taken, 'full_path': full_path, 'gender': gender, 'name': name, 'face_location': face_location, 'face_score': face_score, 'second_face_score': second_face_score, 'dob_str': dob_str, 'ID': ID}

# %%
x_df = pd.DataFrame(data=x)
y_df = pd.DataFrame(data=y)

# %%
img = plt.imread('wiki_labeled/00/10049200_1891-09-16_1958.png')
plt.imshow(img)

# %%
img = plt.imread('wiki_labeled/00/10049200_1891-09-16_1958.png')
print(img.shape)
print(img)
img = np.reshape(img, (10000,1))
print(img.shape)
print(img)

# plt.imshow(img)
# Out:
# (100, 100)
# [[0.8666667  0.827451   0.87058824 ... 0.41568628 0.48235294 0.45882353]
#  [0.87058824 0.8352941  0.8745098  ... 0.52156866 0.6        0.64705884]
#  [0.827451   0.88235295 0.84705883 ... 0.27058825 0.37254903 0.40784314]
#  ...
#  [0.5647059  0.5921569  0.69411767 ... 0.85490197 0.8666667  0.83137256]
#  [0.53333336 0.5411765  0.6039216  ... 0.8392157  0.8509804  0.8235294 ]
#  [0.5137255  0.50980395 0.6        ... 0.827451   0.8352941  0.7607843 ]]
# (10000, 1)
# [[0.8666667 ]
#  [0.827451  ]
#  [0.87058824]
#  ...
#  [0.827451  ]
#  [0.8352941 ]
#  [0.7607843 ]]

# %%
allImg = np.ones([574,10000])

i=0
for f in os.listdir('wiki_labeled/00/'):
    img = imageio.imread('wiki_labeled/00/'+f)
    allImg[i] = img.flatten()
    i= i+1
#    allImg = np.append(allImg, img, axis=1)

# %%
print(allImg.shape)
# Out:
# (574, 10000)

# %%
#print(allImg.shape)
x_train, x_test, y_train, y_test = train_test_split(allImg, agex, test_size = 0.2, random_state = 2)

# x_train = x_train.T
# x_test = x_test.T
print(x_test.shape)
print(y_test.shape)
print(y_train.shape)
print(x_train.shape)
# Out:
# (115, 10000)
# (115,)
# (459,)
# (459, 10000)

# %%
avgXImg = np.mean(x_train, axis=0, keepdims=True)
avgTestXImg = np.mean(x_test, axis=0, keepdims=True)

print(avgXImg.shape)
# Out:
# (1, 10000)

# %%
centXData = x_train - avgXImg
centXData.shape
centTestXData = x_test - avgTestXImg

# %%
#m = np.size(centData,0) - 1
covX = np.cov(centXData.T)

#AAT = np.dot(centData, centData.T)
print(covX.shape)
# Out:
# (10000, 10000)

# %%
U, EvalX, EvecX = np.linalg.svd(covX)



# print(aimg.shape)
# aimg = aimg[:,518]
# print(aimg.shape)
# aimg = aimg.reshape(100,100)
# print(aimg.shape)
# plt.imshow(aimg)

# %%
np.savetxt("Evecs.csv", EvecX[0:20:], delimiter=",")

# %%
print(EvecX.shape)
print(EvalX.shape)
img = EvecX[2].reshape(100,100)
plt.plot(EvalX[1:100:])
plt.show()
# Out:
# (10000, 10000)
# (10000,)

# %%
k = 20

#PCA = EvecX[0:k:]
PCA = np.genfromtxt('Evecs.csv', delimiter=',')
print(PCA.shape)
# Out:
# (20, 10000)

# %%
plt.imshow(PCA[0].reshape(100,100))

# %%
plt.imshow(PCA[2].reshape(100,100))

# %%
omega = np.dot(PCA, centXData.T)
omegaTest = np.dot(PCA, centTestXData.T)

# %%
omega.shape
# Out:
# (20, 459)

# %%
proj = np.dot(PCA.T, omega)

# %%
proj.shape
# Out:
# (10000, 459)

# %%
proj = proj.T
aImg = proj[9]
print(aImg.shape)
aImg = aImg.reshape(100,100)
# Out:
# (10000,)

# %%
plt.imshow(aImg)

# %%
plt.imshow(centXData[9].reshape(100,100))

# %%
def SGD(X, y, w0, alpha, num_iters):
    
    start_iter = 0
    m = len(y)
    print(len(y))
    for it in range(start_iter,num_iters):
        for i in range(0,m):
            rand_ind = np.random.randint(0,m)
            #print(X.shape)
            #print(rand_ind)
            X_i = X[:,rand_ind]
            X_i = X_i.reshape(len(X_i), 1)
            #print(X_i.shape)
            #print(w0.shape)
            X_i = X_i.T
            y_i = y[rand_ind].reshape(1,1)
            prediction = np.dot(X_i, w0)
            yHat = prediction - y_i
            grad = (1/m) * alpha * X_i.T.dot(yHat)
            print("weight" + str(w0[0]))
            print("grad" + str(grad[0]))
            w0 = w0 - grad
            print(i)
           
        
    print(w0)
    return w0

# %%
w0 = np.ones([20,1])

# %%
weights = SGD(omega, y_train, w0, 0.00001, 10)
print(weights.shape)
#print(weights)
# Out:
# 459
# weight[1.]
# grad[0.03275359]
# 0
# weight[0.96724641]
# grad[-0.00124464]
# 1
# weight[0.96849105]
# grad[0.06027307]
# 2
# weight[0.90821798]
# grad[0.06770363]
# 3
# weight[0.84051435]
# grad[1.79207651]
# 4
# weight[-0.95156216]
# grad[-1.15719386]
# 5
# weight[0.2056317]
# grad[0.02509015]
# 6
# weight[0.18054155]
# grad[0.12263356]
# 7
# weight[0.05790799]
# grad[0.02417187]
# 8
# weight[0.03373612]
# grad[-0.02421011]
# 9
# weight[0.05794623]
# grad[-0.48231345]
# 10
# weight[0.54025968]
# grad[0.11935011]
# 11
# weight[0.42090958]
# grad[-0.00995844]
# 12
# weight[0.43086801]
# grad[0.68037978]
# 13
# weight[-0.24951177]
# grad[-0.40429539]
# 14
# weight[0.15478362]
# grad[0.12790882]
# 15
# weight[0.0268748]
# grad[-0.11553417]
# 16
# weight[0.14240898]
# grad[-0.21749938]
# 17
# weight[0.35990836]
# grad[0.34488504]
# 18
# weight[0.01502332]
# grad[0.15318221]
# 19
# weight[-0.13815889]
# grad[-0.18116188]
# 20
# weight[0.04300298]
# grad[-0.00146996]
# 21
# weight[0.04447295]
# grad[0.09305061]
# 22
# weight[-0.04857767]
# grad[-0.31220351]
# 23
# weight[0.26362584]
# grad[0.01045185]
# 24
# weight[0.25317399]
# grad[-0.06475209]
# 25
# weight[0.31792609]
# grad[-0.01380611]
# 26
# weight[0.33173219]
# grad[0.0707408]
# 27
# weight[0.26099139]
# grad[0.10601652]
# 28
# weight[0.15497487]
# grad[-0.00064768]
# 29
# weight[0.15562255]
# grad[0.13748878]
# 30
# weight[0.01813377]
# grad[0.05461609]
# 31
# weight[-0.03648232]
# grad[0.28328409]
# 32
# weight[-0.31976641]
# grad[-0.70806641]
# 33
# weight[0.3883]
# grad[-0.1433943]
# 34
# weight[0.5316943]
# grad[1.10630283]
# 35
# weight[-0.57460853]
# grad[-0.00362044]
# 36
# weight[-0.5709881]
# grad[-0.2120973]
# 37
# weight[-0.3588908]
# grad[-0.04581026]
# 38
# weight[-0.31308054]
# grad[0.05875086]
# 39
# weight[-0.3718314]
# grad[-0.80655405]
# 40
# weight[0.43472265]
# grad[0.01358871]
# 41
# weight[0.42113394]
# grad[0.37691532]
# 42
# weight[0.04421862]
# grad[0.51992691]
# 43
# weight[-0.47570829]
# grad[0.0008365]
# 44
# weight[-0.4765448]
# grad[0.04138251]
# 45
# weight[-0.51792731]
# grad[-0.97419265]
# 46
# weight[0.45626534]
# grad[0.03255104]
# 47
# weight[0.4237143]
# grad[0.03934003]
# 48
# weight[0.38437427]
# grad[0.02085953]
# 49
# weight[0.36351473]
# grad[0.00589998]
# 50
# weight[0.35761475]
# grad[0.64382715]
# 51
# weight[-0.2862124]
# grad[-0.00305248]
# 52
# weight[-0.28315991]
# grad[-0.09971359]
# 53
# weight[-0.18344632]
# grad[0.0175015]
# 54
# weight[-0.20094782]
# grad[0.03753617]
# 55
# weight[-0.23848399]
# grad[0.08781386]
# 56
# weight[-0.32629785]
# grad[-0.0072126]
# 57
# weight[-0.31908525]
# grad[-0.00643889]
# 58
# weight[-0.31264636]
# grad[-0.68504269]
# 59
# weight[0.37239633]
# grad[0.86713117]
# 60
# weight[-0.49473485]
# grad[-0.03543444]
# 61
# weight[-0.4593004]
# grad[-0.9054657]
# 62
# weight[0.44616529]
# grad[0.84525687]
# 63
# weight[-0.39909158]
# grad[-0.01275747]
# 64
# weight[-0.38633411]
# grad[0.12195437]
# 65
# weight[-0.50828848]
# grad[-0.63064874]
# 66
# weight[0.12236026]
# grad[0.21657966]
# 67
# weight[-0.09421939]
# grad[-0.46702963]
# 68
# weight[0.37281024]
# grad[0.37733392]
# 69
# weight[-0.00452368]
# grad[0.03042669]
# 70
# weight[-0.03495037]
# grad[-0.01961041]
# 71
# weight[-0.01533996]
# grad[0.00666522]
# 72
# weight[-0.02200518]
# grad[0.00164281]
# 73
# weight[-0.02364799]
# grad[-0.36066072]
# 74
# weight[0.33701273]
# grad[-0.02835199]
# 75
# weight[0.36536473]
# grad[0.22476537]
# 76
# weight[0.14059936]
# grad[0.07596816]
# 77
# weight[0.06463119]
# grad[0.00445789]
# 78
# weight[0.0601733]
# grad[0.0047621]
# 79
# weight[0.0554112]
# grad[-0.02091749]
# 80
# weight[0.07632869]
# grad[-0.02614941]
# 81
# weight[0.1024781]
# grad[-0.00904392]
# 82
# weight[0.11152201]
# grad[0.05263981]
# 83
# weight[0.05888221]
# grad[0.08523868]
# 84
# weight[-0.02635647]
# grad[0.00534109]
# 85
# weight[-0.03169756]
# grad[-0.0329007]
# 86
# weight[0.00120314]
# grad[0.02465227]
# 87
# weight[-0.02344913]
# grad[-0.06840746]
# 88
# weight[0.04495833]
# grad[-0.07569666]
# 89
# weight[0.12065499]
# grad[0.10625748]
# 90
# weight[0.01439751]
# grad[0.0038228]
# 91
# weight[0.01057471]
# grad[-0.19205481]
# 92
# weight[0.20262952]
# grad[0.03260908]
# 93
# weight[0.17002043]
# grad[0.06088498]
# 94
# weight[0.10913545]
# grad[-0.05910758]
# 95
# weight[0.16824303]
# grad[-0.05127327]
# 96
# weight[0.2195163]
# grad[-0.06333604]
# 97
# weight[0.28285234]
# grad[0.0166953]
# 98
# weight[0.26615705]
# grad[0.3505115]
# 99
# weight[-0.08435446]
# grad[-0.6178299]
# 100
# weight[0.53347544]
# grad[-0.01915562]
# 101
# weight[0.55263107]
# grad[-0.02621797]
# 102
# weight[0.57884904]
# grad[0.24374013]
# 103
# weight[0.33510891]
# grad[-0.07265859]
# 104
# weight[0.40776749]
# grad[0.04055717]
# 105
# weight[0.36721032]
# grad[0.01010194]
# 106
# weight[0.35710838]
# grad[0.80525173]
# 107
# weight[-0.44814335]
# grad[0.03419037]
# 108
# weight[-0.48233372]
# grad[-0.02766134]
# 109
# weight[-0.45467238]
# grad[-0.43783811]
# 110
# weight[-0.01683426]
# grad[0.02034195]
# 111
# weight[-0.03717621]
# grad[0.00603055]
# 112
# weight[-0.04320676]
# grad[-0.03923972]
# 113
# weight[-0.00396704]
# grad[-0.03045397]
# 114
# weight[0.02648693]
# grad[-0.15078873]
# 115
# weight[0.17727566]
# grad[0.04178869]
# 116
# weight[0.13548696]
# grad[0.00633413]
# 117
# weight[0.12915283]
# grad[0.19697639]
# 118
# weight[-0.06782356]
# grad[0.01708179]
# 119
# weight[-0.08490535]
# grad[0.03237891]
# 120
# weight[-0.11728426]
# grad[-0.066044]
# 121
# weight[-0.05124026]
# grad[-0.02173362]
# 122
# weight[-0.02950664]
# grad[0.13169504]
# 123
# weight[-0.16120168]
# grad[0.13278983]
# 124
# weight[-0.29399152]
# grad[-0.67826025]
# 125
# weight[0.38426873]
# grad[0.37473044]
# 126
# weight[0.00953829]
# grad[-0.07027656]
# 127
# weight[0.07981485]
# grad[0.00445484]
# 128
# weight[0.07536001]
# grad[0.00849988]
# 129
# weight[0.06686013]
# grad[0.05886252]
# 130
# weight[0.00799761]
# grad[0.09751187]
# 131
# weight[-0.08951426]
# grad[-0.04079474]
# 132
# weight[-0.04871952]
# grad[0.05176739]
# 133
# weight[-0.10048691]
# grad[-0.02068423]
# 134
# weight[-0.07980268]
# grad[0.06482566]
# 135
# weight[-0.14462834]
# grad[0.01702471]
# 136
# weight[-0.16165304]
# grad[-0.34470738]
# 137
# weight[0.18305434]
# grad[0.06942022]
# 138
# weight[0.11363412]
# grad[-0.11204458]
# 139
# weight[0.2256787]
# grad[0.1728172]
# 140
# weight[0.0528615]
# grad[0.08593314]
# 141
# weight[-0.03307164]
# grad[0.00987004]
# 142
# weight[-0.04294168]
# grad[-0.02015757]
# 143
# weight[-0.02278411]
# grad[-0.02447753]
# 144
# weight[0.00169343]
# grad[-0.05266266]
# 145
# weight[0.05435609]
# grad[0.38468186]
# 146
# weight[-0.33032578]
# grad[-0.09939664]
# 147
# weight[-0.23092914]
# grad[0.00919131]
# 148
# weight[-0.24012045]
# grad[0.01030301]
# 149
# weight[-0.25042346]
# grad[0.00913669]
# 150
# weight[-0.25956015]
# grad[0.01482454]
# 151
# weight[-0.2743847]
# grad[-0.00311125]
# 152
# weight[-0.27127344]
# grad[-0.06888674]
# 153
# weight[-0.2023867]
# grad[-0.048415]
# 154
# weight[-0.1539717]
# grad[-0.00546407]
# 155
# weight[-0.14850763]
# grad[0.0936112]
# 156
# weight[-0.24211883]
# grad[-0.02426263]
# 157
# weight[-0.2178562]
# grad[-0.04555692]
# 158
# weight[-0.17229928]
# grad[-0.00127791]
# 159
# weight[-0.17102137]
# grad[-0.01007999]
# 160
# weight[-0.16094138]
# grad[0.01010159]
# 161
# weight[-0.17104296]
# grad[-0.00169977]
# 162
# weight[-0.16934319]
# grad[-0.23176298]
# 163
# weight[0.06241979]
# grad[0.14425303]
# 164
# weight[-0.08183325]
# grad[-0.20692093]
# 165
# weight[0.12508768]
# grad[0.04218599]
# 166
# weight[0.08290169]
# grad[0.18242447]
# 167
# weight[-0.09952278]
# grad[-0.01158834]
# 168
# weight[-0.08793444]
# grad[0.01099985]
# 169
# weight[-0.0989343]
# grad[-0.08665703]
# 170
# weight[-0.01227726]
# grad[0.01246848]
# 171
# weight[-0.02474575]
# grad[4.7973754e-05]
# 172
# weight[-0.02479372]
# grad[-0.02486649]
# 173
# weight[7.27681888e-05]
# grad[0.15802635]
# 174
# weight[-0.15795358]
# grad[-0.28390241]
# 175
# weight[0.12594884]
# grad[-0.06623131]
# 176
# weight[0.19218014]
# grad[-0.02335147]
# 177
# weight[0.21553162]
# grad[-0.03001478]
# 178
# weight[0.24554639]
# grad[0.55308085]
# 179
# weight[-0.30753445]
# grad[0.0130704]
# 180
# weight[-0.32060486]
# grad[-0.01248675]
# 181
# weight[-0.30811811]
# grad[-0.00116448]
# 182
# weight[-0.30695362]
# grad[0.00148988]
# 183
# weight[-0.3084435]
# grad[-0.26900651]
# 184
# weight[-0.03943699]
# grad[0.00164381]
# 185
# weight[-0.0410808]
# grad[-0.14606848]
# 186
# weight[0.10498768]
# grad[0.16348807]
# 187
# weight[-0.0585004]
# grad[-0.03857268]
# 188
# weight[-0.01992772]
# grad[0.01009927]
# 189
# weight[-0.03002699]
# grad[0.03247043]
# 190
# weight[-0.06249742]
# grad[0.07568369]
# 191
# weight[-0.13818111]
# grad[0.00945262]
# 192
# weight[-0.14763373]
# grad[0.00011425]
# 193
# weight[-0.14774798]
# grad[-0.0013449]
# 194
# weight[-0.14640308]
# grad[0.00027578]
# 195
# weight[-0.14667886]
# grad[0.01081413]
# 196
# weight[-0.15749299]
# grad[-0.01179764]
# 197
# weight[-0.14569536]
# grad[-0.08661984]
# 198
# weight[-0.05907551]
# grad[-0.01076271]
# 199
# weight[-0.0483128]
# grad[-0.06060591]
# 200
# weight[0.01229311]
# grad[0.02248713]
# 201
# weight[-0.01019402]
# grad[-0.04457396]
# 202
# weight[0.03437995]
# grad[-0.00753813]
# 203
# weight[0.04191807]
# grad[-0.04597494]
# 204
# weight[0.08789302]
# grad[0.07055886]
# 205
# weight[0.01733415]
# grad[-0.14322807]
# 206
# weight[0.16056223]
# grad[0.33112947]
# 207
# weight[-0.17056725]
# grad[-0.37487553]
# 208
# weight[0.20430828]
# grad[0.42119684]
# 209
# weight[-0.21688856]
# grad[0.00105412]
# 210
# weight[-0.21794269]
# grad[0.02365949]
# 211
# weight[-0.24160218]
# grad[-0.51058523]
# 212
# weight[0.26898305]
# grad[0.00266639]
# 213
# weight[0.26631666]
# grad[0.14808239]
# 214
# weight[0.11823427]
# grad[0.22659318]
# 215
# weight[-0.10835891]
# grad[0.03826832]
# 216
# weight[-0.14662722]
# grad[0.00030438]
# 217
# weight[-0.14693161]
# grad[-0.0173421]
# 218
# weight[-0.12958951]
# grad[-0.03885168]
# 219
# weight[-0.09073782]
# grad[-0.00272984]
# 220
# weight[-0.08800798]
# grad[0.0407704]
# 221
# weight[-0.12877838]
# grad[-0.06111594]
# 222
# weight[-0.06766244]
# grad[-0.12142619]
# 223
# weight[0.05376375]
# grad[0.00976732]
# 224
# weight[0.04399643]
# grad[-4.97290895e-05]
# 225
# weight[0.04404616]
# grad[-0.0242715]
# 226
# weight[0.06831766]
# grad[-0.00319963]
# 227
# weight[0.07151729]
# grad[0.02102983]
# 228
# weight[0.05048745]
# grad[0.00034761]
# 229
# weight[0.05013984]
# grad[-0.26088867]
# 230
# weight[0.31102851]
# grad[0.02259413]
# 231
# weight[0.28843438]
# grad[0.10627997]
# 232
# weight[0.18215441]
# grad[0.00125075]
# 233
# weight[0.18090366]
# grad[-0.00304503]
# 234
# weight[0.18394869]
# grad[0.02697908]
# 235
# weight[0.15696962]
# grad[-0.00268735]
# 236
# weight[0.15965697]
# grad[0.13317748]
# 237
# weight[0.02647949]
# grad[0.15898113]
# 238
# weight[-0.13250164]
# grad[-0.00512732]
# 239
# weight[-0.12737432]
# grad[-0.00584313]
# 240
# weight[-0.12153119]
# grad[0.01325699]
# 241
# weight[-0.13478818]
# grad[-0.06949744]
# 242
# weight[-0.06529073]
# grad[0.00067597]
# 243
# weight[-0.0659667]
# grad[0.02545475]
# 244
# weight[-0.09142145]
# grad[-0.06378494]
# 245
# weight[-0.02763651]
# grad[0.06202021]
# 246
# weight[-0.08965672]
# grad[-0.03204455]
# 247
# weight[-0.05761217]
# grad[-0.05165985]
# 248
# weight[-0.00595232]
# grad[0.00688942]
# 249
# weight[-0.01284174]
# grad[0.0296591]
# 250
# weight[-0.04250084]
# grad[-0.01346764]
# 251
# weight[-0.02903321]
# grad[-0.01444872]
# 252
# weight[-0.01458449]
# grad[0.00255027]
# 253
# weight[-0.01713476]
# grad[-0.02364813]
# 254
# weight[0.00651337]
# grad[0.05877978]
# 255
# weight[-0.05226641]
# grad[0.00388367]
# 256
# weight[-0.05615008]
# grad[-0.01862534]
# 257
# weight[-0.03752474]
# grad[0.07460677]
# 258
# weight[-0.11213151]
# grad[-0.04941081]
# 259
# weight[-0.0627207]
# grad[-0.13734316]
# 260
# weight[0.07462246]
# grad[0.10683529]
# 261
# weight[-0.03221283]
# grad[-0.02806433]
# 262
# weight[-0.0041485]
# grad[0.0416806]
# 263
# weight[-0.0458291]
# grad[0.00526481]
# 264
# weight[-0.05109391]
# grad[-0.01219574]
# 265
# weight[-0.03889817]
# grad[-0.10168805]
# 266
# weight[0.06278987]
# grad[-0.00194355]
# 267
# weight[0.06473343]
# grad[0.01627954]
# 268
# weight[0.04845388]
# grad[0.01158083]
# 269
# weight[0.03687305]
# grad[0.04703375]
# 270
# weight[-0.0101607]
# grad[0.08067856]
# 271
# weight[-0.09083926]
# grad[0.00462909]
# 272
# weight[-0.09546835]
# grad[0.002614]
# 273
# weight[-0.09808234]
# grad[-0.02330641]
# 274
# weight[-0.07477593]
# grad[-0.00954126]
# 275
# weight[-0.06523467]
# grad[-0.12540644]
# 276
# weight[0.06017177]
# grad[0.04538309]
# 277
# weight[0.01478868]
# grad[-0.00605193]
# 278
# weight[0.02084061]
# grad[0.05634602]
# 279
# weight[-0.03550541]
# grad[-0.00968953]
# 280
# weight[-0.02581588]
# grad[0.01769931]
# 281
# weight[-0.04351519]
# grad[-0.00774957]
# 282
# weight[-0.03576562]
# grad[0.00110406]
# 283
# weight[-0.03686968]
# grad[0.00050656]
# 284
# weight[-0.03737623]
# grad[0.00279755]
# 285
# weight[-0.04017378]
# grad[-0.05279975]
# 286
# weight[0.01262597]
# grad[-0.01933233]
# 287
# weight[0.0319583]
# grad[0.0082464]
# 288
# weight[0.0237119]
# grad[-0.01138247]
# 289
# weight[0.03509437]
# grad[0.08274456]
# 290
# weight[-0.04765019]
# grad[-0.09890024]
# 291
# weight[0.05125005]
# grad[0.00291752]
# 292
# weight[0.04833253]
# grad[0.10942375]
# 293
# weight[-0.06109122]
# grad[0.01060351]
# 294
# weight[-0.07169473]
# grad[0.00568383]
# 295
# weight[-0.07737856]
# grad[-0.0178667]
# 296
# weight[-0.05951186]
# grad[-0.11152846]
# 297
# weight[0.0520166]
# grad[-0.00202533]
# 298
# weight[0.05404193]
# grad[0.0066051]
# 299
# weight[0.04743684]
# grad[0.01957242]
# 300
# weight[0.02786441]
# grad[0.0161144]
# 301
# weight[0.01175002]
# grad[-0.00055382]
# 302
# weight[0.01230384]
# grad[-0.00714932]
# 303
# weight[0.01945316]
# grad[0.06106873]
# 304
# weight[-0.04161557]
# grad[0.0136891]
# 305
# weight[-0.05530468]
# grad[-0.00434952]
# 306
# weight[-0.05095516]
# grad[0.0023233]
# 307
# weight[-0.05327846]
# grad[-0.01501372]
# 308
# weight[-0.03826473]
# grad[0.00098629]
# 309
# weight[-0.03925102]
# grad[-0.08466286]
# 310
# weight[0.04541184]
# grad[0.00064745]
# 311
# weight[0.04476439]
# grad[-0.00490864]
# 312
# weight[0.04967302]
# grad[-0.00123295]
# 313
# weight[0.05090597]
# grad[0.00418545]
# 314
# weight[0.04672052]
# grad[0.03655096]
# 315
# weight[0.01016956]
# grad[-0.02042505]
# 316
# weight[0.03059462]
# grad[-0.00149575]
# 317
# weight[0.03209036]
# grad[0.10713114]
# 318
# weight[-0.07504078]
# grad[-0.10629997]
# 319
# weight[0.03125919]
# grad[0.03036004]
# 320
# weight[0.00089914]
# grad[-0.01495414]
# 321
# weight[0.01585328]
# grad[0.17278098]
# 322
# weight[-0.1569277]
# grad[-0.01781147]
# 323
# weight[-0.13911623]
# grad[0.0078135]
# 324
# weight[-0.14692973]
# grad[-0.24090452]
# 325
# weight[0.09397479]
# grad[0.00196966]
# 326
# weight[0.09200513]
# grad[0.00030146]
# 327
# weight[0.09170367]
# grad[0.00172816]
# 328
# weight[0.08997551]
# grad[-0.00400733]
# 329
# weight[0.09398284]
# grad[0.01261103]
# 330
# weight[0.08137181]
# grad[-0.00022885]
# 331
# weight[0.08160067]
# grad[-0.0012141]
# 332
# weight[0.08281477]
# grad[0.00656173]
# 333
# weight[0.07625304]
# grad[0.21409261]
# 334
# weight[-0.13783957]
# grad[-0.00509346]
# 335
# weight[-0.13274611]
# grad[-0.00325418]
# 336
# weight[-0.12949194]
# grad[-0.02034154]
# 337
# weight[-0.1091504]
# grad[-0.07739375]
# 338
# weight[-0.03175666]
# grad[-0.00067617]
# 339
# weight[-0.03108049]
# grad[0.02346076]
# 340
# weight[-0.05454125]
# grad[0.00067294]
# 341
# weight[-0.05521419]
# grad[-0.0162221]
# 342
# weight[-0.03899209]
# grad[-0.06172621]
# 343
# weight[0.02273412]
# grad[0.05764699]
# 344
# weight[-0.03491287]
# grad[-0.03323232]
# 345
# weight[-0.00168055]
# grad[-0.00973421]
# 346
# weight[0.00805365]
# grad[0.0187486]
# 347
# weight[-0.01069495]
# grad[-0.00139687]
# 348
# weight[-0.00929808]
# grad[-0.01869671]
# 349
# weight[0.00939862]
# grad[-0.0476912]
# 350
# weight[0.05708982]
# grad[0.03233804]
# 351
# weight[0.02475179]
# grad[0.02947276]
# 352
# weight[-0.00472098]
# grad[0.00021846]
# 353
# weight[-0.00493944]
# grad[-0.00357157]
# 354
# weight[-0.00136786]
# grad[0.08596414]
# 355
# weight[-0.08733201]
# grad[-0.00185949]
# 356
# weight[-0.08547252]
# grad[0.00105198]
# 357
# weight[-0.08652451]
# grad[0.02328677]
# 358
# weight[-0.10981127]
# grad[-0.19406769]
# 359
# weight[0.08425641]
# grad[0.15611734]
# 360
# weight[-0.07186093]
# grad[0.00171564]
# 361
# weight[-0.07357657]
# grad[-0.00139996]
# 362
# weight[-0.07217661]
# grad[-0.02355511]
# 363
# weight[-0.0486215]
# grad[-0.02067501]
# 364
# weight[-0.02794649]
# grad[-0.02353229]
# 365
# weight[-0.0044142]
# grad[-5.80911215e-05]
# 366
# weight[-0.00435611]
# grad[-0.01269442]
# 367
# weight[0.00833831]
# grad[0.01465039]
# 368
# weight[-0.00631208]
# grad[-0.0001296]
# 369
# weight[-0.00618248]
# grad[-0.01042222]
# 370
# weight[0.00423974]
# grad[-0.0061779]
# 371
# weight[0.01041764]
# grad[-0.00104759]
# 372
# weight[0.01146523]
# grad[-0.01052858]
# 373
# weight[0.02199382]
# grad[0.03024849]
# 374
# weight[-0.00825467]
# grad[0.01513079]
# 375
# weight[-0.02338547]
# grad[0.02288867]
# 376
# weight[-0.04627414]
# grad[-0.10282418]
# 377
# weight[0.05655004]
# grad[-0.00173234]
# 378
# weight[0.05828238]
# grad[0.1059281]
# 379
# weight[-0.04764572]
# grad[-0.10729788]
# 380
# weight[0.05965215]
# grad[-0.00131698]
# 381
# weight[0.06096913]
# grad[0.02844421]
# 382
# weight[0.03252492]
# grad[0.03857632]
# 383
# weight[-0.00605139]
# grad[0.00452785]
# 384
# weight[-0.01057924]
# grad[-0.02079611]
# 385
# weight[0.01021686]
# grad[-0.13803279]
# 386
# weight[0.14824966]
# grad[0.309518]
# 387
# weight[-0.16126834]
# grad[0.01094059]
# 388
# weight[-0.17220893]
# grad[-0.00021248]
# 389
# weight[-0.17199645]
# grad[-0.09115801]
# 390
# weight[-0.08083845]
# grad[0.0005973]
# 391
# weight[-0.08143574]
# grad[-0.08620453]
# 392
# weight[0.00476878]
# grad[0.00192127]
# 393
# weight[0.00284751]
# grad[0.04438545]
# 394
# weight[-0.04153794]
# grad[-0.09837615]
# 395
# weight[0.05683821]
# grad[0.11026645]
# 396
# weight[-0.05342824]
# grad[-0.00396504]
# 397
# weight[-0.0494632]
# grad[-0.07577519]
# 398
# weight[0.02631199]
# grad[0.11383427]
# 399
# weight[-0.08752228]
# grad[-0.07713868]
# 400
# weight[-0.01038361]
# grad[0.00963833]
# 401
# weight[-0.02002193]
# grad[-0.02892932]
# 402
# weight[0.00890738]
# grad[-0.06153382]
# 403
# weight[0.0704412]
# grad[0.10142079]
# 404
# weight[-0.03097959]
# grad[-0.02378191]
# 405
# weight[-0.00719768]
# grad[0.00833301]
# 406
# weight[-0.01553069]
# grad[-0.00046096]
# 407
# weight[-0.01506972]
# grad[-6.10718093e-05]
# 408
# weight[-0.01500865]
# grad[-0.0094187]
# 409
# weight[-0.00558995]
# grad[-0.04330822]
# 410
# weight[0.03771826]
# grad[0.08106547]
# 411
# weight[-0.04334721]
# grad[-0.02717435]
# 412
# weight[-0.01617286]
# grad[-0.00032613]
# 413
# weight[-0.01584672]
# grad[-0.00178481]
# 414
# weight[-0.01406191]
# grad[0.0025876]
# 415
# weight[-0.01664951]
# grad[-0.05195433]
# 416
# weight[0.03530482]
# grad[0.01030012]
# 417
# weight[0.0250047]
# grad[0.00731697]
# 418
# weight[0.01768772]
# grad[0.00598947]
# 419
# weight[0.01169825]
# grad[-0.02203735]
# 420
# weight[0.03373561]
# grad[0.00472752]
# 421
# weight[0.02900808]
# grad[0.05202485]
# 422
# weight[-0.02301676]
# grad[-0.00046667]
# 423
# weight[-0.02255009]
# grad[-0.06981145]
# 424
# weight[0.04726136]
# grad[0.01687268]
# 425
# weight[0.03038868]
# grad[-0.01962233]
# 426
# weight[0.050011]
# grad[0.04489059]
# 427
# weight[0.00512041]
# grad[0.00272364]
# 428
# weight[0.00239677]
# grad[-0.00493221]
# 429
# weight[0.00732898]
# grad[0.00842062]
# 430
# weight[-0.00109164]
# grad[0.00119649]
# 431
# weight[-0.00228812]
# grad[-0.00865817]
# 432
# weight[0.00637004]
# grad[-0.00061436]
# 433
# weight[0.00698441]
# grad[0.00164999]
# 434
# weight[0.00533442]
# grad[-0.00355324]
# 435
# weight[0.00888766]
# grad[0.02108732]
# 436
# weight[-0.01219966]
# grad[0.02422892]
# 437
# weight[-0.03642858]
# grad[0.00109721]
# 438
# weight[-0.03752579]
# grad[-0.00526236]
# 439
# weight[-0.03226343]
# grad[-0.01838134]
# 440
# weight[-0.01388208]
# grad[-0.0037568]
# 441
# weight[-0.01012528]
# grad[0.0176818]
# 442
# weight[-0.02780708]
# grad[0.01571805]
# 443
# weight[-0.04352513]
# grad[-0.01219389]
# 444
# weight[-0.03133123]
# grad[0.00515746]
# 445
# weight[-0.03648869]
# grad[-0.00361983]
# 446
# weight[-0.03286886]
# grad[-0.00450384]
# 447
# weight[-0.02836502]
# grad[-0.06997949]
# 448
# weight[0.04161447]
# grad[-0.00539244]
# 449
# weight[0.0470069]
# grad[0.00865685]
# 450
# weight[0.03835005]
# grad[0.00226033]
# 451
# weight[0.03608972]
# grad[0.07272538]
# 452
# weight[-0.03663566]
# grad[-0.06536797]
# 453
# weight[0.02873231]
# grad[0.00598779]
# 454
# weight[0.02274452]
# grad[0.0065804]
# 455
# weight[0.01616412]
# grad[1.24025758e-05]
# 456
# weight[0.01615172]
# grad[0.04356144]
# 457
# weight[-0.02740972]
# grad[-0.1091052]
# 458
# weight[0.08169547]
# grad[0.16325812]
# 0
# weight[-0.08156264]
# grad[-0.18148951]
# 1
# weight[0.09992687]
# grad[0.09681224]
# 2
# weight[0.00311464]
# grad[0.02163672]
# 3
# weight[-0.01852209]
# grad[-0.00378833]
# 4
# weight[-0.01473376]
# grad[-0.02465545]
# 5
# weight[0.0099217]
# grad[-0.00209921]
# 6
# weight[0.0120209]
# grad[-0.01143587]
# 7
# weight[0.02345677]
# grad[0.00128668]
# 8
# weight[0.02217009]
# grad[0.00264826]
# 9
# weight[0.01952183]
# grad[-0.00058831]
# 10
# weight[0.02011015]
# grad[0.02439067]
# 11
# weight[-0.00428052]
# grad[-0.00545173]
# 12
# weight[0.00117121]
# grad[-0.01700942]
# 13
# weight[0.01818063]
# grad[0.01938933]
# 14
# weight[-0.0012087]
# grad[-0.01215535]
# 15
# weight[0.01094665]
# grad[0.00065922]
# 16
# weight[0.01028743]
# grad[0.01348077]
# 17
# weight[-0.00319334]
# grad[0.00602455]
# 18
# weight[-0.00921789]
# grad[-0.00548456]
# 19
# weight[-0.00373333]
# grad[0.0079851]
# 20
# weight[-0.01171844]
# grad[-0.00800252]
# 21
# weight[-0.00371591]
# grad[-0.00665344]
# 22
# weight[0.00293753]
# grad[-0.00702724]
# 23
# weight[0.00996477]
# grad[-0.01967207]
# 24
# weight[0.02963684]
# grad[0.00691073]
# 25
# weight[0.02272611]
# grad[0.01075834]
# 26
# weight[0.01196777]
# grad[0.00207965]
# 27
# weight[0.00988813]
# grad[0.00832599]
# 28
# weight[0.00156214]
# grad[-0.00828761]
# 29
# weight[0.00984975]
# grad[0.01722169]
# 30
# weight[-0.00737194]
# grad[-2.80754402e-05]
# 31
# weight[-0.00734387]
# grad[0.00036682]
# 32
# weight[-0.00771069]
# grad[-0.01926524]
# 33
# weight[0.01155455]
# grad[0.01040642]
# 34
# weight[0.00114813]
# grad[0.00023825]
# 35
# weight[0.00090988]
# grad[-0.04204037]
# 36
# weight[0.04295025]
# grad[0.02776126]
# 37
# weight[0.01518899]
# grad[0.01716752]
# 38
# weight[-0.00197853]
# grad[0.00962315]
# 39
# weight[-0.01160168]
# grad[-0.01463312]
# 40
# weight[0.00303144]
# grad[0.02037503]
# 41
# weight[-0.01734359]
# grad[-0.00351631]
# 42
# weight[-0.01382727]
# grad[-0.03278401]
# 43
# weight[0.01895673]
# grad[-0.00642906]
# 44
# weight[0.02538579]
# grad[0.0240646]
# 45
# weight[0.00132119]
# grad[-0.00641528]
# 46
# weight[0.00773647]
# grad[-0.00118917]
# 47
# weight[0.00892564]
# grad[-0.0056228]
# 48
# weight[0.01454844]
# grad[0.03129461]
# 49
# weight[-0.01674617]
# grad[0.00817655]
# 50
# weight[-0.02492272]
# grad[0.0043131]
# 51
# weight[-0.02923582]
# grad[0.0013771]
# 52
# weight[-0.03061292]
# grad[0.00768289]
# 53
# weight[-0.03829581]
# grad[0.0076735]
# 54
# weight[-0.04596931]
# grad[-0.09354664]
# 55
# weight[0.04757733]
# grad[0.00750065]
# 56
# weight[0.04007669]
# grad[0.03599195]
# 57
# weight[0.00408474]
# grad[-0.00773799]
# 58
# weight[0.01182272]
# grad[-0.00304344]
# 59
# weight[0.01486616]
# grad[0.08991287]
# 60
# weight[-0.07504671]
# grad[0.00108962]
# 61
# weight[-0.07613634]
# grad[-0.01396538]
# 62
# weight[-0.06217096]
# grad[-0.00886983]
# 63
# weight[-0.05330113]
# grad[0.00654482]
# 64
# weight[-0.05984595]
# grad[-0.05440914]
# 65
# weight[-0.00543681]
# grad[-0.00075337]
# 66
# weight[-0.00468343]
# grad[-0.02859372]
# 67
# weight[0.02391029]
# grad[0.03568317]
# 68
# weight[-0.01177288]
# grad[-0.03592739]
# 69
# weight[0.02415451]
# grad[-2.01700982e-05]
# 70
# weight[0.02417468]
# grad[0.00076582]
# 71
# weight[0.02340887]
# grad[0.01119865]
# 72
# weight[0.01221022]
# grad[0.02811563]
# 73
# weight[-0.01590541]
# grad[0.00461732]
# 74
# weight[-0.02052274]
# grad[-0.00379356]
# 75
# weight[-0.01672918]
# grad[0.01919385]
# 76
# weight[-0.03592303]
# grad[-0.01823383]
# 77
# weight[-0.0176892]
# grad[0.00772319]
# 78
# weight[-0.02541239]
# grad[-0.00587826]
# 79
# weight[-0.01953413]
# grad[0.00356187]
# 80
# weight[-0.02309601]
# grad[-0.00265632]
# 81
# weight[-0.02043969]
# grad[0.00262478]
# 82
# weight[-0.02306446]
# grad[-0.0518232]
# 83
# weight[0.02875873]
# grad[0.00113912]
# 84
# weight[0.02761962]
# grad[-0.00089512]
# 85
# weight[0.02851474]
# grad[0.05445655]
# 86
# weight[-0.02594182]
# grad[0.00526973]
# 87
# weight[-0.03121155]
# grad[0.00556477]
# 88
# weight[-0.03677632]
# grad[-0.00849241]
# 89
# weight[-0.02828391]
# grad[0.0017653]
# 90
# weight[-0.03004921]
# grad[-0.07787418]
# 91
# weight[0.04782497]
# grad[0.08341613]
# 92
# weight[-0.03559116]
# grad[-0.02050391]
# 93
# weight[-0.01508725]
# grad[-0.00299771]
# 94
# weight[-0.01208954]
# grad[0.01359714]
# 95
# weight[-0.02568669]
# grad[-0.01080407]
# 96
# weight[-0.01488261]
# grad[0.0083129]
# 97
# weight[-0.02319551]
# grad[-0.05975872]
# 98
# weight[0.0365632]
# grad[-0.00052009]
# 99
# weight[0.03708329]
# grad[-0.00196885]
# 100
# weight[0.03905214]
# grad[0.06815667]
# 101
# weight[-0.02910453]
# grad[-0.01679604]
# 102
# weight[-0.01230849]
# grad[-0.00116801]
# 103
# weight[-0.01114048]
# grad[0.00568987]
# 104
# weight[-0.01683035]
# grad[0.00662022]
# 105
# weight[-0.02345057]
# grad[0.00357745]
# 106
# weight[-0.02702802]
# grad[-0.0699483]
# 107
# weight[0.04292028]
# grad[0.03225748]
# 108
# weight[0.01066281]
# grad[0.00034415]
# 109
# weight[0.01031866]
# grad[-0.00077084]
# 110
# weight[0.0110895]
# grad[-0.00122074]
# 111
# weight[0.01231024]
# grad[0.00095059]
# 112
# weight[0.01135965]
# grad[0.01954225]
# 113
# weight[-0.00818261]
# grad[-0.00359824]
# 114
# weight[-0.00458437]
# grad[-0.00682865]
# 115
# weight[0.00224428]
# grad[-0.01064234]
# 116
# weight[0.01288662]
# grad[0.00438353]
# 117
# weight[0.0085031]
# grad[-0.00034758]
# 118
# weight[0.00885068]
# grad[0.01299029]
# 119
# weight[-0.00413961]
# grad[0.01151808]
# 120
# weight[-0.01565769]
# grad[-0.01025648]
# 121
# weight[-0.00540121]
# grad[-0.00784248]
# 122
# weight[0.00244127]
# grad[0.00022809]
# 123
# weight[0.00221318]
# grad[-0.00524036]
# 124
# weight[0.00745354]
# grad[-0.00642296]
# 125
# weight[0.01387649]
# grad[0.00601079]
# 126
# weight[0.0078657]
# grad[0.00269434]
# 127
# weight[0.00517136]
# grad[-0.00239034]
# 128
# weight[0.0075617]
# grad[0.00013397]
# 129
# weight[0.00742773]
# grad[0.00766093]
# 130
# weight[-0.0002332]
# grad[6.72705786e-05]
# 131
# weight[-0.00030047]
# grad[0.01564275]
# 132
# weight[-0.01594321]
# grad[0.00805562]
# 133
# weight[-0.02399883]
# grad[-0.00791429]
# 134
# weight[-0.01608454]
# grad[0.00957737]
# 135
# weight[-0.02566191]
# grad[-0.05009249]
# 136
# weight[0.02443058]
# grad[-0.00685519]
# 137
# weight[0.03128577]
# grad[0.02007276]
# 138
# weight[0.01121301]
# grad[0.00358352]
# 139
# weight[0.00762949]
# grad[-0.00017795]
# 140
# weight[0.00780744]
# grad[0.00383157]
# 141
# weight[0.00397587]
# grad[0.02095961]
# 142
# weight[-0.01698373]
# grad[-0.006907]
# 143
# weight[-0.01007674]
# grad[-0.00092198]
# 144
# weight[-0.00915476]
# grad[-0.009287]
# 145
# weight[0.00013224]
# grad[-0.00217406]
# 146
# weight[0.0023063]
# grad[-0.00707459]
# 147
# weight[0.00938089]
# grad[0.01096873]
# 148
# weight[-0.00158784]
# grad[0.00634201]
# 149
# weight[-0.00792984]
# grad[-0.00439584]
# 150
# weight[-0.00353401]
# grad[-0.01366213]
# 151
# weight[0.01012813]
# grad[-0.01104486]
# 152
# weight[0.02117298]
# grad[0.0003297]
# 153
# weight[0.02084329]
# grad[0.05683071]
# 154
# weight[-0.03598743]
# grad[-0.00327719]
# 155
# weight[-0.03271023]
# grad[-0.00142837]
# 156
# weight[-0.03128186]
# grad[-0.00150275]
# 157
# weight[-0.02977912]
# grad[0.00093082]
# 158
# weight[-0.03070994]
# grad[-0.00279377]
# 159
# weight[-0.02791617]
# grad[0.00588987]
# 160
# weight[-0.03380604]
# grad[-0.0451162]
# 161
# weight[0.01131016]
# grad[0.00460306]
# 162
# weight[0.0067071]
# grad[0.01170984]
# 163
# weight[-0.00500274]
# grad[-0.00964581]
# 164
# weight[0.00464307]
# grad[0.00711656]
# 165
# weight[-0.00247349]
# grad[-0.00063272]
# 166
# weight[-0.00184077]
# grad[1.56961009e-06]
# 167
# weight[-0.00184234]
# grad[-0.01455861]
# 168
# weight[0.01271627]
# grad[0.00167451]
# 169
# weight[0.01104176]
# grad[-0.00541593]
# 170
# weight[0.01645769]
# grad[0.00423826]
# 171
# weight[0.01221943]
# grad[0.00746864]
# 172
# weight[0.00475079]
# grad[-0.00032097]
# 173
# weight[0.00507176]
# grad[-0.00272884]
# 174
# weight[0.0078006]
# grad[0.00167374]
# 175
# weight[0.00612686]
# grad[0.03419028]
# 176
# weight[-0.02806342]
# grad[-0.07007947]
# 177
# weight[0.04201605]
# grad[0.02246475]
# 178
# weight[0.0195513]
# grad[0.00091668]
# 179
# weight[0.01863462]
# grad[0.02257114]
# 180
# weight[-0.00393652]
# grad[0.00186551]
# 181
# weight[-0.00580203]
# grad[-0.00255654]
# 182
# weight[-0.00324548]
# grad[-0.00665874]
# 183
# weight[0.00341326]
# grad[0.01168684]
# 184
# weight[-0.00827359]
# grad[0.00476195]
# 185
# weight[-0.01303554]
# grad[-0.001558]
# 186
# weight[-0.01147754]
# grad[-0.00028485]
# 187
# weight[-0.01119269]
# grad[-0.00137071]
# 188
# weight[-0.00982198]
# grad[0.02830645]
# 189
# weight[-0.03812843]
# grad[0.00430486]
# 190
# weight[-0.04243328]
# grad[-0.08652841]
# 191
# weight[0.04409513]
# grad[0.09497209]
# 192
# weight[-0.05087696]
# grad[-0.05413612]
# 193
# weight[0.00325916]
# grad[-0.01514316]
# 194
# weight[0.01840232]
# grad[0.05223908]
# 195
# weight[-0.03383676]
# grad[-0.03407222]
# 196
# weight[0.00023545]
# grad[-0.00073949]
# 197
# weight[0.00097495]
# grad[-0.00209649]
# 198
# weight[0.00307144]
# grad[-0.00117022]
# 199
# weight[0.00424165]
# grad[0.05186059]
# 200
# weight[-0.04761894]
# grad[-0.11056553]
# 201
# weight[0.0629466]
# grad[0.02557782]
# 202
# weight[0.03736878]
# grad[-0.00183514]
# 203
# weight[0.03920392]
# grad[0.00268742]
# 204
# weight[0.03651649]
# grad[0.01408234]
# 205
# weight[0.02243415]
# grad[0.02364371]
# 206
# weight[-0.00120956]
# grad[-0.01424165]
# 207
# weight[0.01303209]
# grad[0.00270269]
# 208
# weight[0.0103294]
# grad[0.00944196]
# 209
# weight[0.00088744]
# grad[0.00065384]
# 210
# weight[0.0002336]
# grad[-0.00540105]
# 211
# weight[0.00563465]
# grad[-0.00173326]
# 212
# weight[0.00736791]
# grad[0.01915868]
# 213
# weight[-0.01179077]
# grad[-6.98638658e-06]
# 214
# weight[-0.01178379]
# grad[-0.00081145]
# 215
# weight[-0.01097234]
# grad[-0.03878129]
# 216
# weight[0.02780896]
# grad[0.0505581]
# 217
# weight[-0.02274914]
# grad[-0.00227889]
# 218
# weight[-0.02047025]
# grad[-0.00186407]
# 219
# weight[-0.01860618]
# grad[-0.08267721]
# 220
# weight[0.06407103]
# grad[0.02276398]
# 221
# weight[0.04130705]
# grad[0.00016722]
# 222
# weight[0.04113983]
# grad[0.01032384]
# 223
# weight[0.03081599]
# grad[0.11145002]
# 224
# weight[-0.08063403]
# grad[-0.02842615]
# 225
# weight[-0.05220788]
# grad[-0.05196977]
# 226
# weight[-0.00023811]
# grad[-0.01464318]
# 227
# weight[0.01440507]
# grad[0.02787567]
# 228
# weight[-0.0134706]
# grad[0.00386374]
# 229
# weight[-0.01733434]
# grad[-0.00646297]
# 230
# weight[-0.01087137]
# grad[-0.00474883]
# 231
# weight[-0.00612253]
# grad[-0.01371988]
# 232
# weight[0.00759734]
# grad[0.00070224]
# 233
# weight[0.00689511]
# grad[0.00020755]
# 234
# weight[0.00668755]
# grad[-0.00033139]
# 235
# weight[0.00701894]
# grad[0.00265614]
# 236
# weight[0.0043628]
# grad[0.01360021]
# 237
# weight[-0.00923741]
# grad[0.00467079]
# 238
# weight[-0.0139082]
# grad[-0.01576684]
# 239
# weight[0.00185864]
# grad[0.00137748]
# 240
# weight[0.00048117]
# grad[4.83270073e-06]
# 241
# weight[0.00047633]
# grad[0.00574933]
# 242
# weight[-0.005273]
# grad[3.42466777e-08]
# 243
# weight[-0.00527303]
# grad[8.9072388e-05]
# 244
# weight[-0.00536211]
# grad[0.00084981]
# 245
# weight[-0.00621192]
# grad[-0.00420145]
# 246
# weight[-0.00201047]
# grad[0.00509112]
# 247
# weight[-0.00710159]
# grad[0.0027334]
# 248
# weight[-0.00983499]
# grad[-0.00270957]
# 249
# weight[-0.00712542]
# grad[-0.00192663]
# 250
# weight[-0.00519879]
# grad[-0.02766729]
# 251
# weight[0.0224685]
# grad[0.00457892]
# 252
# weight[0.01788958]
# grad[0.02881288]
# 253
# weight[-0.0109233]
# grad[-0.00037703]
# 254
# weight[-0.01054627]
# grad[-0.00314929]
# 255
# weight[-0.00739698]
# grad[-0.0021503]
# 256
# weight[-0.00524668]
# grad[0.00024267]
# 257
# weight[-0.00548934]
# grad[-0.00659761]
# 258
# weight[0.00110826]
# grad[0.00037369]
# 259
# weight[0.00073457]
# grad[0.00543511]
# 260
# weight[-0.00470054]
# grad[-0.01804364]
# 261
# weight[0.0133431]
# grad[0.01276954]
# 262
# weight[0.00057356]
# grad[-8.95311306e-05]
# 263
# weight[0.00066309]
# grad[6.70023488e-05]
# 264
# weight[0.00059609]
# grad[-4.14386763e-05]
# 265
# weight[0.00063753]
# grad[0.00344802]
# 266
# weight[-0.00281049]
# grad[0.00763953]
# 267
# weight[-0.01045002]
# grad[-0.00250465]
# 268
# weight[-0.00794537]
# grad[0.00148269]
# 269
# weight[-0.00942806]
# grad[0.01046113]
# 270
# weight[-0.01988919]
# grad[-0.05156183]
# 271
# weight[0.03167264]
# grad[0.00126195]
# 272
# weight[0.03041069]
# grad[0.05937652]
# 273
# weight[-0.02896583]
# grad[-2.71841098e-05]
# 274
# weight[-0.02893864]
# grad[-1.4287693e-05]
# 275
# weight[-0.02892435]
# grad[-0.00340524]
# 276
# weight[-0.02551911]
# grad[-0.01872914]
# 277
# weight[-0.00678997]
# grad[0.00046703]
# 278
# weight[-0.007257]
# grad[0.00023868]
# 279
# weight[-0.00749568]
# grad[0.01408873]
# 280
# weight[-0.02158441]
# grad[0.00077993]
# 281
# weight[-0.02236435]
# grad[-0.00072505]
# 282
# weight[-0.02163929]
# grad[-0.00109002]
# 283
# weight[-0.02054927]
# grad[0.00321286]
# 284
# weight[-0.02376213]
# grad[-0.05130823]
# 285
# weight[0.0275461]
# grad[0.0588273]
# 286
# weight[-0.0312812]
# grad[-0.06181614]
# 287
# weight[0.03053494]
# grad[-0.0008837]
# 288
# weight[0.03141863]
# grad[6.74200043e-06]
# 289
# weight[0.03141189]
# grad[0.00041949]
# 290
# weight[0.03099241]
# grad[-0.00183121]
# 291
# weight[0.03282361]
# grad[-0.00147835]
# 292
# weight[0.03430196]
# grad[0.00026039]
# 293
# weight[0.03404157]
# grad[0.00093174]
# 294
# weight[0.03310983]
# grad[0.03491719]
# 295
# weight[-0.00180736]
# grad[-0.00171832]
# 296
# weight[-8.90433763e-05]
# grad[-0.00065152]
# 297
# weight[0.00056248]
# grad[0.00327281]
# 298
# weight[-0.00271034]
# grad[-0.00411365]
# 299
# weight[0.00140332]
# grad[-0.00075285]
# 300
# weight[0.00215617]
# grad[-0.00272648]
# 301
# weight[0.00488265]
# grad[-0.00212743]
# 302
# weight[0.00701008]
# grad[0.01749921]
# 303
# weight[-0.01048913]
# grad[-0.00555653]
# 304
# weight[-0.0049326]
# grad[-5.05122878e-05]
# 305
# weight[-0.00488209]
# grad[-0.00376817]
# 306
# weight[-0.00111392]
# grad[-0.00906178]
# 307
# weight[0.00794786]
# grad[0.00212488]
# 308
# weight[0.00582298]
# grad[-0.00014241]
# 309
# weight[0.00596538]
# grad[0.00023469]
# 310
# weight[0.00573069]
# grad[0.00257825]
# 311
# weight[0.00315244]
# grad[0.00177564]
# 312
# weight[0.00137679]
# grad[-0.00154958]
# 313
# weight[0.00292637]
# grad[0.00161063]
# 314
# weight[0.00131575]
# grad[0.0009235]
# 315
# weight[0.00039224]
# grad[-0.01201663]
# 316
# weight[0.01240887]
# grad[0.00596481]
# 317
# weight[0.00644406]
# grad[-0.00908166]
# 318
# weight[0.01552572]
# grad[0.00082189]
# 319
# weight[0.01470383]
# grad[-0.00034338]
# 320
# weight[0.01504722]
# grad[-0.00075302]
# 321
# weight[0.01580024]
# grad[0.01244361]
# 322
# weight[0.00335663]
# grad[0.0001307]
# 323
# weight[0.00322593]
# grad[-0.00254046]
# 324
# weight[0.00576639]
# grad[0.00147283]
# 325
# weight[0.00429356]
# grad[-0.00035908]
# 326
# weight[0.00465264]
# grad[0.01011168]
# 327
# weight[-0.00545904]
# grad[-0.00272753]
# 328
# weight[-0.00273151]
# grad[0.00088449]
# 329
# weight[-0.003616]
# grad[-0.01021239]
# 330
# weight[0.00659639]
# grad[0.00595671]
# 331
# weight[0.00063968]
# grad[0.00017647]
# 332
# weight[0.00046321]
# grad[-0.00397603]
# 333
# weight[0.00443924]
# grad[0.00914519]
# 334
# weight[-0.00470595]
# grad[6.14738932e-05]
# 335
# weight[-0.00476742]
# grad[0.00155545]
# 336
# weight[-0.00632287]
# grad[-0.01327107]
# 337
# weight[0.0069482]
# grad[0.00319419]
# 338
# weight[0.00375401]
# grad[-0.00092974]
# 339
# weight[0.00468375]
# grad[0.00144063]
# 340
# weight[0.00324312]
# grad[0.0165961]
# 341
# weight[-0.01335298]
# grad[0.0029313]
# 342
# weight[-0.01628428]
# grad[-0.03773107]
# 343
# weight[0.0214468]
# grad[0.00515072]
# 344
# weight[0.01629608]
# grad[0.00034941]
# 345
# weight[0.01594666]
# grad[0.08413193]
# 346
# weight[-0.06818527]
# grad[-0.01450722]
# 347
# weight[-0.05367805]
# grad[-0.1707983]
# 348
# weight[0.11712025]
# grad[0.03054181]
# 349
# weight[0.08657844]
# grad[0.07564918]
# 350
# weight[0.01092926]
# grad[0.00046883]
# 351
# weight[0.01046043]
# grad[-0.00107419]
# 352
# weight[0.01153461]
# grad[0.00395352]
# 353
# weight[0.00758109]
# grad[-0.00021143]
# 354
# weight[0.00779253]
# grad[0.00310882]
# 355
# weight[0.00468371]
# grad[0.00066073]
# 356
# weight[0.00402298]
# grad[0.00022803]
# 357
# weight[0.00379495]
# grad[0.00151416]
# 358
# weight[0.00228078]
# grad[4.71806291e-06]
# 359
# weight[0.00227607]
# grad[0.00031039]
# 360
# weight[0.00196568]
# grad[-0.00460035]
# 361
# weight[0.00656603]
# grad[0.00591946]
# 362
# weight[0.00064656]
# grad[0.00030799]
# 363
# weight[0.00033857]
# grad[-0.00047834]
# 364
# weight[0.0008169]
# grad[-0.00866763]
# 365
# weight[0.00948454]
# grad[-0.00038911]
# 366
# weight[0.00987364]
# grad[-0.00240108]
# 367
# weight[0.01227473]
# grad[0.00090807]
# 368
# weight[0.01136666]
# grad[-0.00541769]
# 369
# weight[0.01678435]
# grad[0.00146818]
# 370
# weight[0.01531617]
# grad[0.02254789]
# 371
# weight[-0.00723172]
# grad[-0.00309022]
# 372
# weight[-0.00414149]
# grad[-0.02114525]
# 373
# weight[0.01700376]
# grad[0.00818107]
# 374
# weight[0.00882269]
# grad[0.00681358]
# 375
# weight[0.00200911]
# grad[-0.00191978]
# 376
# weight[0.00392888]
# grad[0.00346597]
# 377
# weight[0.00046291]
# grad[0.0085665]
# 378
# weight[-0.00810359]
# grad[-0.00526086]
# 379
# weight[-0.00284273]
# grad[-0.02074079]
# 380
# weight[0.01789806]
# grad[0.00319517]
# 381
# weight[0.01470289]
# grad[0.02171213]
# 382
# weight[-0.00700923]
# grad[0.00021036]
# 383
# weight[-0.0072196]
# grad[-0.00060518]
# 384
# weight[-0.00661441]
# grad[-0.00786583]
# 385
# weight[0.00125142]
# grad[-0.01067325]
# 386
# weight[0.01192467]
# grad[0.00156027]
# 387
# weight[0.0103644]
# grad[0.00424666]
# 388
# weight[0.00611773]
# grad[-0.00304085]
# 389
# weight[0.00915858]
# grad[0.00690509]
# 390
# weight[0.00225349]
# grad[7.90800035e-06]
# 391
# weight[0.00224558]
# grad[0.00133588]
# 392
# weight[0.00090971]
# grad[0.06698502]
# 393
# weight[-0.06607531]
# grad[-0.14424831]
# 394
# weight[0.07817299]
# grad[0.11373016]
# 395
# weight[-0.03555717]
# grad[-0.0047638]
# 396
# weight[-0.03079337]
# grad[-0.04879442]
# 397
# weight[0.01800105]
# grad[0.00917583]
# 398
# weight[0.00882522]
# grad[-6.49515237e-05]
# 399
# weight[0.00889017]
# grad[-0.00388656]
# 400
# weight[0.01277673]
# grad[0.07956894]
# 401
# weight[-0.06679221]
# grad[-0.02459593]
# 402
# weight[-0.04219628]
# grad[-0.13200655]
# 403
# weight[0.08981028]
# grad[0.02056984]
# 404
# weight[0.06924044]
# grad[0.13229734]
# 405
# weight[-0.0630569]
# grad[-0.15016884]
# 406
# weight[0.08711194]
# grad[0.00678448]
# 407
# weight[0.08032745]
# grad[0.07125366]
# 408
# weight[0.00907379]
# grad[0.00981719]
# 409
# weight[-0.0007434]
# grad[-0.01004277]
# 410
# weight[0.00929937]
# grad[-0.00086858]
# 411
# weight[0.01016795]
# grad[0.00431457]
# 412
# weight[0.00585338]
# grad[-9.4902202e-06]
# 413
# weight[0.00586287]
# grad[-0.00864191]
# 414
# weight[0.01450478]
# grad[0.00765956]
# 415
# weight[0.00684521]
# grad[0.00994653]
# 416
# weight[-0.00310132]
# grad[0.00297796]
# 417
# weight[-0.00607929]
# grad[-0.00539564]
# 418
# weight[-0.00068364]
# grad[-0.001267]
# 419
# weight[0.00058336]
# grad[0.00457787]
# 420
# weight[-0.00399451]
# grad[-0.0169654]
# 421
# weight[0.01297089]
# grad[-0.00222004]
# 422
# weight[0.01519093]
# grad[0.00631879]
# 423
# weight[0.00887214]
# grad[0.05419251]
# 424
# weight[-0.04532037]
# grad[-0.06807708]
# 425
# weight[0.02275671]
# grad[0.00775143]
# 426
# weight[0.01500528]
# grad[-0.00425546]
# 427
# weight[0.01926074]
# grad[-3.48762051e-05]
# 428
# weight[0.01929562]
# grad[0.03004637]
# 429
# weight[-0.01075075]
# grad[-0.00082752]
# 430
# weight[-0.00992324]
# grad[-0.00074074]
# 431
# weight[-0.0091825]
# grad[-0.00453518]
# 432
# weight[-0.00464732]
# grad[-0.0033784]
# 433
# weight[-0.00126892]
# grad[-0.00082525]
# 434
# weight[-0.00044367]
# grad[-0.02037004]
# 435
# weight[0.01992637]
# grad[0.00423342]
# 436
# weight[0.01569295]
# grad[0.00600546]
# 437
# weight[0.00968748]
# grad[0.01671287]
# 438
# weight[-0.00702539]
# grad[0.00160473]
# 439
# weight[-0.00863012]
# grad[-0.0014661]
# 440
# weight[-0.00716402]
# grad[-0.00412495]
# 441
# weight[-0.00303906]
# grad[-0.02095089]
# 442
# weight[0.01791183]
# grad[-0.00054944]
# 443
# weight[0.01846126]
# grad[0.03305889]
# 444
# weight[-0.01459763]
# grad[-0.04395417]
# 445
# weight[0.02935654]
# grad[0.04004488]
# 446
# weight[-0.01068834]
# grad[0.00495485]
# 447
# weight[-0.01564319]
# grad[-0.01159996]
# 448
# weight[-0.00404323]
# grad[-0.02326051]
# 449
# weight[0.01921728]
# grad[0.02529674]
# 450
# weight[-0.00607947]
# grad[0.0006092]
# 451
# weight[-0.00668867]
# grad[0.00013201]
# 452
# weight[-0.00682068]
# grad[0.00468091]
# 453
# weight[-0.01150159]
# grad[-0.00070108]
# 454
# weight[-0.0108005]
# grad[-0.00079002]
# 455
# weight[-0.01001049]
# grad[-0.00025577]
# 456
# weight[-0.00975472]
# grad[0.00109731]
# 457
# weight[-0.01085203]
# grad[-0.01279094]
# 458
# weight[0.00193891]
# grad[0.00230847]
# 0
# weight[-0.00036955]
# grad[-0.00138547]
# 1
# weight[0.00101592]
# grad[0.00112882]
# 2
# weight[-0.0001129]
# grad[0.04140323]
# 3
# weight[-0.04151613]
# grad[0.00015389]
# 4
# weight[-0.04167002]
# grad[-0.11080481]
# 5
# weight[0.06913479]
# grad[0.01539279]
# 6
# weight[0.053742]
# grad[0.04401496]
# 7
# weight[0.00972703]
# grad[0.00580313]
# 8
# weight[0.00392391]
# grad[-0.00019264]
# 9
# weight[0.00411655]
# grad[0.00560284]
# 10
# weight[-0.00148629]
# grad[-0.00121414]
# 11
# weight[-0.00027216]
# grad[-0.00075198]
# 12
# weight[0.00047983]
# grad[-0.00819559]
# 13
# weight[0.00867542]
# grad[-0.00748854]
# 14
# weight[0.01616396]
# grad[0.02411907]
# 15
# weight[-0.00795511]
# grad[-0.00243298]
# 16
# weight[-0.00552214]
# grad[-0.00529915]
# 17
# weight[-0.00022298]
# grad[-0.0049695]
# 18
# weight[0.00474652]
# grad[-0.0032714]
# 19
# weight[0.00801792]
# grad[0.01943704]
# 20
# weight[-0.01141912]
# grad[5.22110739e-05]
# 21
# weight[-0.01147133]
# grad[0.0005772]
# 22
# weight[-0.01204853]
# grad[0.00033587]
# 23
# weight[-0.0123844]
# grad[-0.02764357]
# 24
# weight[0.01525917]
# grad[0.00159868]
# 25
# weight[0.01366049]
# grad[0.05159619]
# 26
# weight[-0.0379357]
# grad[-0.08637064]
# 27
# weight[0.04843494]
# grad[-0.00048348]
# 28
# weight[0.04891842]
# grad[0.04390615]
# 29
# weight[0.00501227]
# grad[0.00038454]
# 30
# weight[0.00462773]
# grad[-0.00171941]
# 31
# weight[0.00634714]
# grad[-0.00015616]
# 32
# weight[0.0065033]
# grad[0.0010606]
# 33
# weight[0.0054427]
# grad[-0.00077634]
# 34
# weight[0.00621904]
# grad[-0.00049922]
# 35
# weight[0.00671826]
# grad[-0.00432121]
# 36
# weight[0.01103947]
# grad[0.01698444]
# 37
# weight[-0.00594498]
# grad[0.00056068]
# 38
# weight[-0.00650565]
# grad[2.69994016e-05]
# 39
# weight[-0.00653265]
# grad[-0.00129023]
# 40
# weight[-0.00524242]
# grad[0.00024106]
# 41
# weight[-0.00548349]
# grad[-0.01824398]
# 42
# weight[0.01276049]
# grad[-0.00119233]
# 43
# weight[0.01395282]
# grad[0.00041465]
# 44
# weight[0.01353818]
# grad[0.01440783]
# 45
# weight[-0.00086965]
# grad[-0.00955611]
# 46
# weight[0.00868646]
# grad[0.01643897]
# 47
# weight[-0.00775252]
# grad[0.00084461]
# 48
# weight[-0.00859712]
# grad[-0.00046597]
# 49
# weight[-0.00813115]
# grad[-0.02814375]
# 50
# weight[0.02001259]
# grad[-0.00136231]
# 51
# weight[0.0213749]
# grad[9.19180081e-05]
# 52
# weight[0.02128299]
# grad[0.00641524]
# 53
# weight[0.01486775]
# grad[0.07063401]
# 54
# weight[-0.05576626]
# grad[-0.03564527]
# 55
# weight[-0.02012099]
# grad[-0.00418195]
# 56
# weight[-0.01593904]
# grad[-0.00129469]
# 57
# weight[-0.01464436]
# grad[0.00412733]
# 58
# weight[-0.01877169]
# grad[0.00209179]
# 59
# weight[-0.02086348]
# grad[0.00029404]
# 60
# weight[-0.02115752]
# grad[-0.00123836]
# 61
# weight[-0.01991915]
# grad[-0.00121584]
# 62
# weight[-0.01870332]
# grad[0.00061176]
# 63
# weight[-0.01931507]
# grad[0.00092136]
# 64
# weight[-0.02023643]
# grad[-0.00100503]
# 65
# weight[-0.0192314]
# grad[-0.00055526]
# 66
# weight[-0.01867614]
# grad[-0.04007958]
# 67
# weight[0.02140344]
# grad[0.04433729]
# 68
# weight[-0.02293386]
# grad[-0.00494593]
# 69
# weight[-0.01798793]
# grad[-0.04505908]
# 70
# weight[0.02707115]
# grad[-0.00075455]
# 71
# weight[0.0278257]
# grad[-2.55400824e-05]
# 72
# weight[0.02785124]
# grad[0.00011024]
# 73
# weight[0.027741]
# grad[0.00901244]
# 74
# weight[0.01872856]
# grad[0.01474703]
# 75
# weight[0.00398153]
# grad[-0.00053385]
# 76
# weight[0.00451538]
# grad[5.46769457e-05]
# 77
# weight[0.00446071]
# grad[-0.00729447]
# 78
# weight[0.01175517]
# grad[0.00099714]
# 79
# weight[0.01075803]
# grad[0.02452949]
# 80
# weight[-0.01377146]
# grad[0.00230706]
# 81
# weight[-0.01607852]
# grad[-0.03355898]
# 82
# weight[0.01748046]
# grad[0.00032204]
# 83
# weight[0.01715841]
# grad[0.00909885]
# 84
# weight[0.00805956]
# grad[-0.00102559]
# 85
# weight[0.00908515]
# grad[-0.00083966]
# 86
# weight[0.00992481]
# grad[0.02019075]
# 87
# weight[-0.01026594]
# grad[0.00493686]
# 88
# weight[-0.0152028]
# grad[-0.00236334]
# 89
# weight[-0.01283945]
# grad[7.65779411e-05]
# 90
# weight[-0.01291603]
# grad[-0.00295537]
# 91
# weight[-0.00996066]
# grad[-0.024399]
# 92
# weight[0.01443834]
# grad[0.02287753]
# 93
# weight[-0.00843919]
# grad[-0.00801765]
# 94
# weight[-0.00042154]
# grad[0.00035043]
# 95
# weight[-0.00077197]
# grad[-0.00068281]
# 96
# weight[-8.91535578e-05]
# grad[0.00316628]
# 97
# weight[-0.00325544]
# grad[-0.00062985]
# 98
# weight[-0.00262558]
# grad[-0.00637269]
# 99
# weight[0.00374711]
# grad[-0.00044179]
# 100
# weight[0.0041889]
# grad[0.0092713]
# 101
# weight[-0.0050824]
# grad[0.00128558]
# 102
# weight[-0.00636798]
# grad[0.00094096]
# 103
# weight[-0.00730894]
# grad[-0.00149045]
# 104
# weight[-0.00581848]
# grad[-0.01750717]
# 105
# weight[0.01168869]
# grad[0.04107082]
# 106
# weight[-0.02938213]
# grad[-0.00140963]
# 107
# weight[-0.0279725]
# grad[-0.00313376]
# 108
# weight[-0.02483874]
# grad[-0.00445247]
# 109
# weight[-0.02038627]
# grad[-0.01154977]
# 110
# weight[-0.00883651]
# grad[0.00032927]
# 111
# weight[-0.00916578]
# grad[-0.00281643]
# 112
# weight[-0.00634934]
# grad[0.00410674]
# 113
# weight[-0.01045608]
# grad[-0.00071428]
# 114
# weight[-0.0097418]
# grad[7.51012472e-05]
# 115
# weight[-0.0098169]
# grad[0.00517699]
# 116
# weight[-0.01499389]
# grad[0.00106657]
# 117
# weight[-0.01606046]
# grad[-0.03967181]
# 118
# weight[0.02361134]
# grad[0.00824573]
# 119
# weight[0.01536561]
# grad[0.0133973]
# 120
# weight[0.00196832]
# grad[-8.00350359e-05]
# 121
# weight[0.00204835]
# grad[0.00608708]
# 122
# weight[-0.00403873]
# grad[0.00232741]
# 123
# weight[-0.00636614]
# grad[-0.01004322]
# 124
# weight[0.00367708]
# grad[-0.00044386]
# 125
# weight[0.00412094]
# grad[0.00251104]
# 126
# weight[0.0016099]
# grad[-0.00128889]
# 127
# weight[0.00289879]
# grad[-0.01152726]
# 128
# weight[0.01442605]
# grad[0.00866664]
# 129
# weight[0.00575941]
# grad[0.00047983]
# 130
# weight[0.00527957]
# grad[0.00015303]
# 131
# weight[0.00512654]
# grad[-0.00092011]
# 132
# weight[0.00604665]
# grad[0.03658242]
# 133
# weight[-0.03053576]
# grad[-0.03628957]
# 134
# weight[0.00575381]
# grad[0.05810023]
# 135
# weight[-0.05234642]
# grad[-0.10901328]
# 136
# weight[0.05666686]
# grad[0.09050479]
# 137
# weight[-0.03383793]
# grad[-0.05862214]
# 138
# weight[0.02478421]
# grad[-0.00026955]
# 139
# weight[0.02505376]
# grad[-0.00215262]
# 140
# weight[0.02720637]
# grad[0.0043886]
# 141
# weight[0.02281777]
# grad[0.00817974]
# 142
# weight[0.01463803]
# grad[-0.00479151]
# 143
# weight[0.01942954]
# grad[0.0022487]
# 144
# weight[0.01718084]
# grad[0.00021278]
# 145
# weight[0.01696806]
# grad[-0.00111346]
# 146
# weight[0.01808152]
# grad[0.03104993]
# 147
# weight[-0.01296841]
# grad[-0.00263976]
# 148
# weight[-0.01032865]
# grad[-0.00992659]
# 149
# weight[-0.00040206]
# grad[0.00080882]
# 150
# weight[-0.00121088]
# grad[0.00035206]
# 151
# weight[-0.00156294]
# grad[0.00382179]
# 152
# weight[-0.00538473]
# grad[-0.04451686]
# 153
# weight[0.03913213]
# grad[-0.00014785]
# 154
# weight[0.03927998]
# grad[0.06139995]
# 155
# weight[-0.02211996]
# grad[0.00216035]
# 156
# weight[-0.02428032]
# grad[-0.05711578]
# 157
# weight[0.03283546]
# grad[0.00154313]
# 158
# weight[0.03129233]
# grad[0.00211601]
# 159
# weight[0.02917632]
# grad[0.00176294]
# 160
# weight[0.02741338]
# grad[0.03594795]
# 161
# weight[-0.00853457]
# grad[-0.00124653]
# 162
# weight[-0.00728804]
# grad[-0.00418294]
# 163
# weight[-0.0031051]
# grad[-0.00107355]
# 164
# weight[-0.00203155]
# grad[-0.00665692]
# 165
# weight[0.00462537]
# grad[0.00057573]
# 166
# weight[0.00404963]
# grad[0.0013282]
# 167
# weight[0.00272143]
# grad[0.00035049]
# 168
# weight[0.00237095]
# grad[0.00200854]
# 169
# weight[0.0003624]
# grad[0.00067996]
# 170
# weight[-0.00031756]
# grad[-0.00027734]
# 171
# weight[-4.02213006e-05]
# grad[0.00320188]
# 172
# weight[-0.0032421]
# grad[-0.01033717]
# 173
# weight[0.00709507]
# grad[0.00113754]
# 174
# weight[0.00595753]
# grad[0.00805636]
# 175
# weight[-0.00209883]
# grad[0.00049383]
# 176
# weight[-0.00259266]
# grad[0.02278331]
# 177
# weight[-0.02537597]
# grad[-0.00156275]
# 178
# weight[-0.02381322]
# grad[-0.00055061]
# 179
# weight[-0.02326261]
# grad[-0.0090199]
# 180
# weight[-0.01424271]
# grad[-0.03360926]
# 181
# weight[0.01936655]
# grad[0.00351396]
# 182
# weight[0.01585259]
# grad[0.00331195]
# 183
# weight[0.01254064]
# grad[0.00944734]
# 184
# weight[0.0030933]
# grad[0.00172452]
# 185
# weight[0.00136877]
# grad[-0.00092975]
# 186
# weight[0.00229852]
# grad[0.00792485]
# 187
# weight[-0.00562633]
# grad[-0.00137473]
# 188
# weight[-0.0042516]
# grad[-0.01796232]
# 189
# weight[0.01371072]
# grad[0.02723501]
# 190
# weight[-0.01352429]
# grad[-0.00110923]
# 191
# weight[-0.01241506]
# grad[-0.04120764]
# 192
# weight[0.02879257]
# grad[0.00495458]
# 193
# weight[0.023838]
# grad[0.01028608]
# 194
# weight[0.01355192]
# grad[-0.00204885]
# 195
# weight[0.01560077]
# grad[0.00031317]
# 196
# weight[0.0152876]
# grad[0.02468268]
# 197
# weight[-0.00939508]
# grad[-0.0035154]
# 198
# weight[-0.00587968]
# grad[-0.00241414]
# 199
# weight[-0.00346554]
# grad[-0.00066382]
# 200
# weight[-0.00280172]
# grad[0.00269751]
# 201
# weight[-0.00549923]
# grad[-0.0130643]
# 202
# weight[0.00756508]
# grad[0.00060422]
# 203
# weight[0.00696086]
# grad[-7.48834003e-05]
# 204
# weight[0.00703575]
# grad[-0.00238261]
# 205
# weight[0.00941835]
# grad[0.01202389]
# 206
# weight[-0.00260554]
# grad[0.00585437]
# 207
# weight[-0.00845991]
# grad[-0.00646819]
# 208
# weight[-0.00199173]
# grad[0.00316334]
# 209
# weight[-0.00515507]
# grad[-0.0066834]
# 210
# weight[0.00152833]
# grad[-0.00010129]
# 211
# weight[0.00162961]
# grad[0.01531788]
# 212
# weight[-0.01368827]
# grad[0.00073896]
# 213
# weight[-0.01442723]
# grad[-0.00031903]
# 214
# weight[-0.0141082]
# grad[-0.00029221]
# 215
# weight[-0.01381599]
# grad[-0.00671017]
# 216
# weight[-0.00710582]
# grad[2.32796097e-05]
# 217
# weight[-0.0071291]
# grad[6.03025502e-05]
# 218
# weight[-0.0071894]
# grad[0.00084426]
# 219
# weight[-0.00803367]
# grad[0.00077543]
# 220
# weight[-0.00880909]
# grad[-5.16289136e-06]
# 221
# weight[-0.00880393]
# grad[0.00152373]
# 222
# weight[-0.01032765]
# grad[0.00042471]
# 223
# weight[-0.01075237]
# grad[-0.00127841]
# 224
# weight[-0.00947395]
# grad[0.00039923]
# 225
# weight[-0.00987318]
# grad[0.00058776]
# 226
# weight[-0.01046094]
# grad[-0.02619378]
# 227
# weight[0.01573284]
# grad[6.00151959e-06]
# 228
# weight[0.01572683]
# grad[0.00456268]
# 229
# weight[0.01116415]
# grad[-0.00077111]
# 230
# weight[0.01193527]
# grad[0.00080553]
# 231
# weight[0.01112974]
# grad[8.6521295e-05]
# 232
# weight[0.01104322]
# grad[-0.00121949]
# 233
# weight[0.01226271]
# grad[0.00159142]
# 234
# weight[0.01067129]
# grad[0.00030313]
# 235
# weight[0.01036815]
# grad[-0.00083503]
# 236
# weight[0.01120319]
# grad[-0.00013245]
# 237
# weight[0.01133563]
# grad[5.53705101e-05]
# 238
# weight[0.01128026]
# grad[0.01605547]
# 239
# weight[-0.00477521]
# grad[-0.02917357]
# 240
# weight[0.02439836]
# grad[0.01738824]
# 241
# weight[0.00701012]
# grad[-0.00134799]
# 242
# weight[0.00835811]
# grad[-0.00047756]
# 243
# weight[0.00883567]
# grad[-0.00453303]
# 244
# weight[0.0133687]
# grad[0.00030179]
# 245
# weight[0.01306691]
# grad[0.01287664]
# 246
# weight[0.00019027]
# grad[0.00750365]
# 247
# weight[-0.00731337]
# grad[0.00132907]
# 248
# weight[-0.00864244]
# grad[-0.02421013]
# 249
# weight[0.01556769]
# grad[0.00091216]
# 250
# weight[0.01465553]
# grad[-0.00296807]
# 251
# weight[0.01762361]
# grad[-0.00044034]
# 252
# weight[0.01806395]
# grad[0.00097218]
# 253
# weight[0.01709177]
# grad[-0.0007296]
# 254
# weight[0.01782137]
# grad[-0.00053628]
# 255
# weight[0.01835765]
# grad[-0.00064435]
# 256
# weight[0.019002]
# grad[0.00664908]
# 257
# weight[0.01235292]
# grad[-0.00157079]
# 258
# weight[0.01392371]
# grad[0.00539722]
# 259
# weight[0.00852648]
# grad[0.00307807]
# 260
# weight[0.00544841]
# grad[0.00802568]
# 261
# weight[-0.00257726]
# grad[0.00115698]
# ...
# 75
# weight[-0.00838653]
# grad[-0.01048901]
# 76
# weight[0.00210248]
# grad[-0.00037331]
# 77
# weight[0.00247579]
# grad[-0.00067948]
# 78
# weight[0.00315527]
# grad[0.001305]
# 79
# weight[0.00185027]
# grad[-1.92829371e-05]
# 80
# weight[0.00186955]
# grad[-0.00220158]
# 81
# weight[0.00407113]
# grad[0.01283261]
# 82
# weight[-0.00876148]
# grad[-0.00564853]
# 83
# weight[-0.00311295]
# grad[0.00381051]
# 84
# weight[-0.00692346]
# grad[-0.00086994]
# 85
# weight[-0.00605352]
# grad[-0.01047355]
# 86
# weight[0.00442003]
# grad[0.00082809]
# 87
# weight[0.00359193]
# grad[0.00591962]
# 88
# weight[-0.00232768]
# grad[0.00010477]
# 89
# weight[-0.00243245]
# grad[-0.00215725]
# 90
# weight[-0.0002752]
# grad[0.00015993]
# 91
# weight[-0.00043513]
# grad[0.00624085]
# 92
# weight[-0.00667598]
# grad[0.00043134]
# 93
# weight[-0.00710732]
# grad[-0.00028443]
# 94
# weight[-0.00682288]
# grad[0.00020858]
# 95
# weight[-0.00703146]
# grad[0.00357102]
# 96
# weight[-0.01060247]
# grad[-0.00145806]
# 97
# weight[-0.00914441]
# grad[-0.00065716]
# 98
# weight[-0.00848725]
# grad[0.00900968]
# 99
# weight[-0.01749693]
# grad[-0.00056965]
# 100
# weight[-0.01692729]
# grad[-0.00110191]
# 101
# weight[-0.01582537]
# grad[-0.00061579]
# 102
# weight[-0.01520958]
# grad[-0.03861967]
# 103
# weight[0.02341009]
# grad[-0.00020528]
# 104
# weight[0.02361537]
# grad[-0.00040374]
# 105
# weight[0.02401911]
# grad[-0.00064153]
# 106
# weight[0.02466064]
# grad[0.01138582]
# 107
# weight[0.01327482]
# grad[0.00584177]
# 108
# weight[0.00743305]
# grad[0.00279103]
# 109
# weight[0.00464202]
# grad[-0.00142479]
# 110
# weight[0.0060668]
# grad[0.00885256]
# 111
# weight[-0.00278576]
# grad[0.00021333]
# 112
# weight[-0.00299908]
# grad[-0.00069623]
# 113
# weight[-0.00230285]
# grad[-0.0083168]
# 114
# weight[0.00601394]
# grad[-0.00771188]
# 115
# weight[0.01372583]
# grad[0.00763896]
# 116
# weight[0.00608687]
# grad[-0.00162001]
# 117
# weight[0.00770687]
# grad[-0.00524971]
# 118
# weight[0.01295658]
# grad[0.00118259]
# 119
# weight[0.01177399]
# grad[0.00023156]
# 120
# weight[0.01154243]
# grad[0.0021708]
# 121
# weight[0.00937163]
# grad[-0.00014952]
# 122
# weight[0.00952115]
# grad[0.01542934]
# 123
# weight[-0.00590819]
# grad[-0.02839833]
# 124
# weight[0.02249015]
# grad[0.00341003]
# 125
# weight[0.01908011]
# grad[0.00215487]
# 126
# weight[0.01692524]
# grad[0.00016799]
# 127
# weight[0.01675725]
# grad[-0.00010673]
# 128
# weight[0.01686398]
# grad[0.00459929]
# 129
# weight[0.01226469]
# grad[0.00422584]
# 130
# weight[0.00803885]
# grad[3.36269956e-06]
# 131
# weight[0.00803549]
# grad[0.00738983]
# 132
# weight[0.00064566]
# grad[0.00147493]
# 133
# weight[-0.00082927]
# grad[-0.00123959]
# 134
# weight[0.00041032]
# grad[0.00056004]
# 135
# weight[-0.00014972]
# grad[0.00097735]
# 136
# weight[-0.00112708]
# grad[-6.15717747e-05]
# 137
# weight[-0.0010655]
# grad[0.00034686]
# 138
# weight[-0.00141236]
# grad[-0.0002333]
# 139
# weight[-0.00117907]
# grad[-0.00118375]
# 140
# weight[4.68261836e-06]
# grad[-0.01308247]
# 141
# weight[0.01308715]
# grad[0.00189293]
# 142
# weight[0.01119422]
# grad[0.01517516]
# 143
# weight[-0.00398093]
# grad[-0.00062534]
# 144
# weight[-0.00335559]
# grad[0.00147938]
# 145
# weight[-0.00483497]
# grad[-0.00012591]
# 146
# weight[-0.00470906]
# grad[-0.0015418]
# 147
# weight[-0.00316726]
# grad[0.00128317]
# 148
# weight[-0.00445043]
# grad[0.0005507]
# 149
# weight[-0.00500113]
# grad[-0.00037416]
# 150
# weight[-0.00462697]
# grad[-0.00087212]
# 151
# weight[-0.00375485]
# grad[0.00047544]
# 152
# weight[-0.00423029]
# grad[0.00779499]
# 153
# weight[-0.01202528]
# grad[-0.00356572]
# 154
# weight[-0.00845956]
# grad[-0.02584327]
# 155
# weight[0.01738371]
# grad[0.00268021]
# 156
# weight[0.0147035]
# grad[0.00327091]
# 157
# weight[0.0114326]
# grad[0.01355909]
# 158
# weight[-0.00212649]
# grad[0.00077261]
# 159
# weight[-0.0028991]
# grad[-0.00184335]
# 160
# weight[-0.00105575]
# grad[0.00121746]
# 161
# weight[-0.0022732]
# grad[0.00042215]
# 162
# weight[-0.00269536]
# grad[-0.02148878]
# 163
# weight[0.01879342]
# grad[0.01089063]
# 164
# weight[0.00790279]
# grad[0.02100656]
# 165
# weight[-0.01310378]
# grad[-0.00060147]
# 166
# weight[-0.01250231]
# grad[-0.00148106]
# 167
# weight[-0.01102124]
# grad[-0.0024138]
# 168
# weight[-0.00860744]
# grad[-0.00086119]
# 169
# weight[-0.00774625]
# grad[0.0013482]
# 170
# weight[-0.00909445]
# grad[-0.03235668]
# 171
# weight[0.02326223]
# grad[0.04857417]
# 172
# weight[-0.02531194]
# grad[-0.01776364]
# 173
# weight[-0.00754829]
# grad[0.00594321]
# 174
# weight[-0.0134915]
# grad[-0.00075143]
# 175
# weight[-0.01274007]
# grad[-0.00757968]
# 176
# weight[-0.00516039]
# grad[-0.00835808]
# 177
# weight[0.00319769]
# grad[-0.00012016]
# 178
# weight[0.00331785]
# grad[-0.00140976]
# 179
# weight[0.00472761]
# grad[-0.00027945]
# 180
# weight[0.00500705]
# grad[-0.00145486]
# 181
# weight[0.00646192]
# grad[0.00072185]
# 182
# weight[0.00574007]
# grad[1.99415015e-06]
# 183
# weight[0.00573807]
# grad[0.0003807]
# 184
# weight[0.00535737]
# grad[0.00102713]
# 185
# weight[0.00433025]
# grad[0.00561171]
# 186
# weight[-0.00128147]
# grad[-0.00092999]
# 187
# weight[-0.00035148]
# grad[-0.00052314]
# 188
# weight[0.00017166]
# grad[0.00546369]
# 189
# weight[-0.00529203]
# grad[-0.00218159]
# 190
# weight[-0.00311044]
# grad[2.54007548e-05]
# 191
# weight[-0.00313584]
# grad[0.01146278]
# 192
# weight[-0.01459863]
# grad[-0.0007922]
# 193
# weight[-0.01380642]
# grad[-0.04013022]
# 194
# weight[0.0263238]
# grad[0.00618615]
# 195
# weight[0.02013765]
# grad[-8.74286629e-05]
# 196
# weight[0.02022508]
# grad[0.00279088]
# 197
# weight[0.0174342]
# grad[-0.00083829]
# 198
# weight[0.01827249]
# grad[0.03520764]
# 199
# weight[-0.01693516]
# grad[-0.00791553]
# 200
# weight[-0.00901963]
# grad[-0.02900846]
# 201
# weight[0.01998883]
# grad[0.00147196]
# 202
# weight[0.01851688]
# grad[0.00602264]
# 203
# weight[0.01249424]
# grad[0.00446207]
# 204
# weight[0.00803217]
# grad[0.00076104]
# 205
# weight[0.00727114]
# grad[0.00389224]
# 206
# weight[0.0033789]
# grad[-0.00251213]
# 207
# weight[0.00589103]
# grad[0.00259028]
# 208
# weight[0.00330075]
# grad[-0.0044036]
# 209
# weight[0.00770435]
# grad[0.01127528]
# 210
# weight[-0.00357093]
# grad[-0.00048777]
# 211
# weight[-0.00308316]
# grad[0.00759179]
# 212
# weight[-0.01067495]
# grad[-0.00050988]
# 213
# weight[-0.01016508]
# grad[0.00296187]
# 214
# weight[-0.01312695]
# grad[-0.00263663]
# 215
# weight[-0.01049031]
# grad[0.00438995]
# 216
# weight[-0.01488026]
# grad[-0.00070136]
# 217
# weight[-0.0141789]
# grad[1.86401364e-05]
# 218
# weight[-0.01419754]
# grad[-0.02238249]
# 219
# weight[0.00818495]
# grad[-0.0057346]
# 220
# weight[0.01391955]
# grad[-0.00058139]
# 221
# weight[0.01450093]
# grad[-0.00087502]
# 222
# weight[0.01537596]
# grad[0.00127477]
# 223
# weight[0.01410118]
# grad[-0.00097415]
# 224
# weight[0.01507533]
# grad[0.00411249]
# 225
# weight[0.01096285]
# grad[-0.00098822]
# 226
# weight[0.01195106]
# grad[0.00027185]
# 227
# weight[0.01167921]
# grad[0.0011389]
# 228
# weight[0.01054031]
# grad[0.017779]
# 229
# weight[-0.0072387]
# grad[-3.00436618e-06]
# 230
# weight[-0.00723569]
# grad[-0.00105285]
# 231
# weight[-0.00618284]
# grad[-0.00044822]
# 232
# weight[-0.00573462]
# grad[-0.00104187]
# 233
# weight[-0.00469275]
# grad[0.00105927]
# 234
# weight[-0.00575202]
# grad[0.00497855]
# 235
# weight[-0.01073058]
# grad[-0.02404681]
# 236
# weight[0.01331623]
# grad[0.02102839]
# 237
# weight[-0.00771216]
# grad[-0.02366188]
# 238
# weight[0.01594972]
# grad[-0.00104844]
# 239
# weight[0.01699816]
# grad[0.02613989]
# 240
# weight[-0.00914173]
# grad[7.36431604e-05]
# 241
# weight[-0.00921538]
# grad[-0.00179698]
# 242
# weight[-0.0074184]
# grad[0.00120931]
# 243
# weight[-0.00862771]
# grad[-0.00028541]
# 244
# weight[-0.0083423]
# grad[0.00438958]
# 245
# weight[-0.01273188]
# grad[-0.00215475]
# 246
# weight[-0.01057713]
# grad[-0.00176931]
# 247
# weight[-0.00880782]
# grad[-0.0010213]
# 248
# weight[-0.00778652]
# grad[5.60503898e-05]
# 249
# weight[-0.00784257]
# grad[0.00525843]
# 250
# weight[-0.01310101]
# grad[-0.00499667]
# 251
# weight[-0.00810433]
# grad[-0.02654257]
# 252
# weight[0.01843824]
# grad[0.04572325]
# 253
# weight[-0.02728502]
# grad[-0.00120909]
# 254
# weight[-0.02607593]
# grad[-0.00584628]
# 255
# weight[-0.02022965]
# grad[-0.00241712]
# 256
# weight[-0.01781253]
# grad[-0.04336707]
# 257
# weight[0.02555454]
# grad[0.00566162]
# 258
# weight[0.01989292]
# grad[0.00899806]
# 259
# weight[0.01089486]
# grad[0.01483546]
# 260
# weight[-0.0039406]
# grad[-0.01532931]
# 261
# weight[0.01138872]
# grad[0.00260754]
# 262
# weight[0.00878117]
# grad[0.02824383]
# 263
# weight[-0.01946266]
# grad[-0.00270477]
# 264
# weight[-0.01675789]
# grad[-0.00494683]
# 265
# weight[-0.01181106]
# grad[-0.00540485]
# 266
# weight[-0.00640621]
# grad[0.0006243]
# 267
# weight[-0.00703052]
# grad[-0.00121094]
# 268
# weight[-0.00581958]
# grad[-0.00726879]
# 269
# weight[0.00144922]
# grad[-0.00613596]
# 270
# weight[0.00758517]
# grad[-0.0015088]
# 271
# weight[0.00909398]
# grad[0.00300111]
# 272
# weight[0.00609287]
# grad[0.00887609]
# 273
# weight[-0.00278323]
# grad[-0.00023221]
# 274
# weight[-0.00255101]
# grad[0.00032216]
# 275
# weight[-0.00287317]
# grad[-0.00014433]
# 276
# weight[-0.00272884]
# grad[0.00014135]
# 277
# weight[-0.00287019]
# grad[-0.00865233]
# 278
# weight[0.00578214]
# grad[-0.00052741]
# 279
# weight[0.00630955]
# grad[-0.00125791]
# 280
# weight[0.00756746]
# grad[0.01393903]
# 281
# weight[-0.00637157]
# grad[-0.01997416]
# 282
# weight[0.01360259]
# grad[0.00072846]
# 283
# weight[0.01287413]
# grad[0.00109768]
# 284
# weight[0.01177645]
# grad[0.00121099]
# 285
# weight[0.01056546]
# grad[-0.00274478]
# 286
# weight[0.01331024]
# grad[-0.00102369]
# 287
# weight[0.01433392]
# grad[0.00812969]
# 288
# weight[0.00620424]
# grad[0.00036649]
# 289
# weight[0.00583775]
# grad[0.00511716]
# 290
# weight[0.00072059]
# grad[0.01407409]
# 291
# weight[-0.0133535]
# grad[5.74617176e-05]
# 292
# weight[-0.01341096]
# grad[-0.00407914]
# 293
# weight[-0.00933182]
# grad[0.0010094]
# 294
# weight[-0.01034122]
# grad[-0.00129182]
# 295
# weight[-0.0090494]
# grad[0.00053713]
# 296
# weight[-0.00958653]
# grad[0.00031068]
# 297
# weight[-0.0098972]
# grad[-0.02217769]
# 298
# weight[0.01228049]
# grad[0.00743096]
# 299
# weight[0.00484954]
# grad[9.66338195e-05]
# 300
# weight[0.0047529]
# grad[-0.00063177]
# 301
# weight[0.00538467]
# grad[0.00134382]
# 302
# weight[0.00404084]
# grad[-0.00239284]
# 303
# weight[0.00643368]
# grad[0.00065199]
# 304
# weight[0.00578169]
# grad[-0.00012769]
# 305
# weight[0.00590938]
# grad[-6.79090302e-06]
# 306
# weight[0.00591617]
# grad[0.00136036]
# 307
# weight[0.0045558]
# grad[0.00079178]
# 308
# weight[0.00376402]
# grad[0.01604723]
# 309
# weight[-0.01228321]
# grad[0.00101865]
# 310
# weight[-0.01330186]
# grad[-0.036513]
# 311
# weight[0.02321113]
# grad[0.00129014]
# 312
# weight[0.02192099]
# grad[0.00049037]
# 313
# weight[0.02143062]
# grad[0.04288917]
# 314
# weight[-0.02145855]
# grad[0.00027368]
# 315
# weight[-0.02173224]
# grad[0.00304342]
# 316
# weight[-0.02477565]
# grad[0.00016702]
# 317
# weight[-0.02494267]
# grad[7.33532218e-05]
# 318
# weight[-0.02501602]
# grad[-0.03863582]
# 319
# weight[0.0136198]
# grad[0.00136079]
# 320
# weight[0.01225901]
# grad[-0.00044678]
# 321
# weight[0.01270579]
# grad[-1.8485101e-05]
# 322
# weight[0.01272427]
# grad[0.02512272]
# 323
# weight[-0.01239844]
# grad[0.000241]
# 324
# weight[-0.01263945]
# grad[-0.00014299]
# 325
# weight[-0.01249645]
# grad[-0.00057572]
# 326
# weight[-0.01192073]
# grad[-0.0410269]
# 327
# weight[0.02910617]
# grad[0.00919726]
# 328
# weight[0.01990891]
# grad[0.03305019]
# 329
# weight[-0.01314127]
# grad[-0.0107569]
# 330
# weight[-0.00238438]
# grad[0.00245524]
# 331
# weight[-0.00483961]
# grad[-0.02450143]
# 332
# weight[0.01966182]
# grad[0.00293913]
# 333
# weight[0.01672269]
# grad[0.01606529]
# 334
# weight[0.00065741]
# grad[-0.00165513]
# 335
# weight[0.00231254]
# grad[-0.00505278]
# 336
# weight[0.00736532]
# grad[-0.00098195]
# 337
# weight[0.00834727]
# grad[0.00110651]
# 338
# weight[0.00724077]
# grad[0.00225452]
# 339
# weight[0.00498625]
# grad[0.00320115]
# 340
# weight[0.0017851]
# grad[0.00338139]
# 341
# weight[-0.00159629]
# grad[-0.00356426]
# 342
# weight[0.00196797]
# grad[0.01213507]
# 343
# weight[-0.01016709]
# grad[0.00019172]
# 344
# weight[-0.01035881]
# grad[-0.03324364]
# 345
# weight[0.02288483]
# grad[0.00155304]
# 346
# weight[0.02133179]
# grad[0.00179345]
# 347
# weight[0.01953834]
# grad[-0.00033536]
# 348
# weight[0.0198737]
# grad[0.00929247]
# 349
# weight[0.01058123]
# grad[-0.00099587]
# 350
# weight[0.0115771]
# grad[-0.00180147]
# 351
# weight[0.01337857]
# grad[0.00469221]
# 352
# weight[0.00868637]
# grad[0.00022235]
# 353
# weight[0.00846402]
# grad[0.0013448]
# 354
# weight[0.00711922]
# grad[0.00202596]
# 355
# weight[0.00509326]
# grad[0.00234742]
# 356
# weight[0.00274584]
# grad[1.88448758e-05]
# 357
# weight[0.002727]
# grad[0.00040254]
# 358
# weight[0.00232445]
# grad[-2.35149537e-05]
# 359
# weight[0.00234797]
# grad[-0.00717916]
# 360
# weight[0.00952713]
# grad[0.01207462]
# 361
# weight[-0.00254749]
# grad[0.0033595]
# 362
# weight[-0.005907]
# grad[-0.00695808]
# 363
# weight[0.00105109]
# grad[0.00224074]
# 364
# weight[-0.00118965]
# grad[0.00975607]
# 365
# weight[-0.01094573]
# grad[-0.00180647]
# 366
# weight[-0.00913926]
# grad[-0.0050032]
# 367
# weight[-0.00413606]
# grad[-0.017111]
# 368
# weight[0.01297494]
# grad[0.00013866]
# 369
# weight[0.01283629]
# grad[0.00291168]
# 370
# weight[0.00992461]
# grad[-0.00098294]
# 371
# weight[0.01090754]
# grad[0.01770959]
# 372
# weight[-0.00680204]
# grad[7.38709822e-05]
# 373
# weight[-0.00687592]
# grad[-0.00124649]
# 374
# weight[-0.00562943]
# grad[0.00102729]
# 375
# weight[-0.00665672]
# grad[0.00641318]
# 376
# weight[-0.0130699]
# grad[-0.00019306]
# 377
# weight[-0.01287683]
# grad[-0.00151769]
# 378
# weight[-0.01135914]
# grad[8.39124032e-06]
# 379
# weight[-0.01136754]
# grad[-0.00084775]
# 380
# weight[-0.01051978]
# grad[-0.0059848]
# 381
# weight[-0.00453498]
# grad[0.00092792]
# 382
# weight[-0.0054629]
# grad[-0.0266157]
# 383
# weight[0.02115281]
# grad[0.00964947]
# 384
# weight[0.01150334]
# grad[0.018976]
# 385
# weight[-0.00747266]
# grad[-2.89598251e-05]
# 386
# weight[-0.0074437]
# grad[-0.00016952]
# 387
# weight[-0.00727418]
# grad[-0.011815]
# 388
# weight[0.00454082]
# grad[-0.00748208]
# 389
# weight[0.0120229]
# grad[0.0084191]
# 390
# weight[0.0036038]
# grad[-0.00816671]
# 391
# weight[0.01177051]
# grad[0.00203166]
# 392
# weight[0.00973885]
# grad[1.58484793e-05]
# 393
# weight[0.009723]
# grad[0.00244917]
# 394
# weight[0.00727382]
# grad[0.00564859]
# 395
# weight[0.00162523]
# grad[0.00065604]
# 396
# weight[0.00096919]
# grad[0.01965937]
# 397
# weight[-0.01869017]
# grad[-0.00122282]
# 398
# weight[-0.01746735]
# grad[0.0004598]
# 399
# weight[-0.01792715]
# grad[-0.02671209]
# 400
# weight[0.00878494]
# grad[0.00916249]
# 401
# weight[-0.00037755]
# grad[-0.00063417]
# 402
# weight[0.00025662]
# grad[0.0003742]
# 403
# weight[-0.00011757]
# grad[-0.00057338]
# 404
# weight[0.0004558]
# grad[0.00025231]
# 405
# weight[0.00020349]
# grad[-0.00107736]
# 406
# weight[0.00128085]
# grad[0.00010164]
# 407
# weight[0.00117921]
# grad[-0.00072086]
# 408
# weight[0.00190007]
# grad[-0.00033374]
# 409
# weight[0.00223381]
# grad[0.00214398]
# 410
# weight[8.98328001e-05]
# grad[-0.00647257]
# 411
# weight[0.00656241]
# grad[-1.78118316e-06]
# 412
# weight[0.00656419]
# grad[-0.00701145]
# 413
# weight[0.01357564]
# grad[0.01164117]
# 414
# weight[0.00193446]
# grad[0.00019316]
# 415
# weight[0.0017413]
# grad[-0.00203459]
# 416
# weight[0.00377588]
# grad[-0.00085917]
# 417
# weight[0.00463506]
# grad[-0.00082]
# 418
# weight[0.00545506]
# grad[-6.8133948e-06]
# 419
# weight[0.00546187]
# grad[-0.00036507]
# 420
# weight[0.00582694]
# grad[0.00112243]
# 421
# weight[0.00470451]
# grad[0.00836547]
# 422
# weight[-0.00366096]
# grad[0.00382994]
# 423
# weight[-0.0074909]
# grad[0.00062275]
# 424
# weight[-0.00811365]
# grad[-0.00244171]
# 425
# weight[-0.00567194]
# grad[-0.00021353]
# 426
# weight[-0.0054584]
# grad[0.00151963]
# 427
# weight[-0.00697803]
# grad[-0.00721171]
# 428
# weight[0.00023367]
# grad[0.00094167]
# 429
# weight[-0.000708]
# grad[-0.00016155]
# 430
# weight[-0.00054644]
# grad[0.00060117]
# 431
# weight[-0.00114761]
# grad[-4.24300863e-05]
# 432
# weight[-0.00110518]
# grad[-0.00023235]
# 433
# weight[-0.00087283]
# grad[2.17694345e-05]
# 434
# weight[-0.0008946]
# grad[-0.0035198]
# 435
# weight[0.0026252]
# grad[0.00592967]
# 436
# weight[-0.00330447]
# grad[0.00504973]
# 437
# weight[-0.0083542]
# grad[-0.00092879]
# 438
# weight[-0.00742541]
# grad[0.00097775]
# 439
# weight[-0.00840316]
# grad[-0.00181752]
# 440
# weight[-0.00658564]
# grad[-0.03552624]
# 441
# weight[0.0289406]
# grad[0.00200358]
# 442
# weight[0.02693702]
# grad[0.00153724]
# 443
# weight[0.02539978]
# grad[9.31084411e-05]
# 444
# weight[0.02530667]
# grad[0.00242721]
# 445
# weight[0.02287946]
# grad[0.00081011]
# 446
# weight[0.02206935]
# grad[0.00851526]
# 447
# weight[0.01355409]
# grad[0.00166275]
# 448
# weight[0.01189134]
# grad[-0.00038637]
# 449
# weight[0.01227771]
# grad[0.02022934]
# 450
# weight[-0.00795163]
# grad[0.00093842]
# 451
# weight[-0.00889005]
# grad[-0.03388012]
# 452
# weight[0.02499006]
# grad[0.00506477]
# 453
# weight[0.0199253]
# grad[-8.75289515e-06]
# 454
# weight[0.01993405]
# grad[-0.00030154]
# 455
# weight[0.02023559]
# grad[0.04723738]
# 456
# weight[-0.02700179]
# grad[-0.00109658]
# 457
# weight[-0.02590521]
# grad[-0.05900477]
# 458
# [[ 0.03309956]
#  [ 0.0040836 ]
#  [-0.00162468]
#  [ 0.01094786]
#  [ 0.00084797]
#  [-0.01258365]
#  [-0.00171534]
#  [ 0.00791203]
#  [-0.00219719]
#  [-0.00232376]
#  [ 0.00358252]
#  [ 0.00476625]
#  [-0.00205461]
#  [-0.00934774]
#  [ 0.00359537]
#  [-0.01042661]
#  [-0.001081  ]
#  [ 0.00077405]
#  [-0.00178649]
#  [-0.00680684]]
# (20, 1)

# %%
pred = np.zeros([115,1])
p = 0
#print(omegaTest.shape)
#print(weights.shape)
#print(weights)
for i in range(0,115,1):
    pred[i] = np.dot(omegaTest[:,i], weights)
    print(pred[i])
    p = p + 1
error = pred - y_test
#print(pred.shape)
#print(pred)

#print(error)
# Out:
# [-155.70905278]
# [-54.89856596]
# [301.79443485]
# [15.70343617]
# [301.79443485]
# [-256.1101041]
# [-4.21013333]
# [106.09707545]
# [-58.74074933]
# [18.17094993]
# [301.79443485]
# [301.79443485]
# [-29.0700735]
# [301.79443485]
# [-198.47225704]
# [166.0592948]
# [-10.65473598]
# [28.57970571]
# [-395.55347203]
# [202.0274673]
# [-96.31114695]
# [95.0205112]
# [-214.29376842]
# [301.79443485]
# [301.79443485]
# [53.97091067]
# [80.04908126]
# [-146.61676576]
# [30.76347632]
# [-11.45466054]
# [88.69070895]
# [-69.47138542]
# [-25.86202835]
# [-150.8125179]
# [-171.23193013]
# [68.95776123]
# [301.79443485]
# [301.79443485]
# [17.46316146]
# [-61.22546738]
# [-53.21612797]
# [-78.21761565]
# [-94.43088329]
# [47.72823761]
# [301.79443485]
# [-395.55347203]
# [140.7909116]
# [34.70722773]
# [39.63328]
# [-101.13748372]
# [301.79443485]
# [-34.96839508]
# [-134.6778709]
# [-105.69271431]
# [10.79853569]
# [-153.09277097]
# [301.79443485]
# [48.88399889]
# [-105.63468916]
# [301.79443485]
# [17.82480397]
# [-37.60460531]
# [-85.18038999]
# [35.15834594]
# [-52.29883598]
# [6.98908055]
# [158.26793283]
# [-18.50869567]
# [-300.79467871]
# [35.52864776]
# [-288.29452041]
# [-24.07966942]
# [-213.73552622]
# [44.85472875]
# [-1.93545585]
# [-46.40008713]
# [42.54089594]
# [301.79443485]
# [-2.68683063]
# [-129.46073358]
# [-92.97683855]
# [301.79443485]
# [-395.55347203]
# [153.00519471]
# [301.79443485]
# [-23.74182322]
# [-123.4227834]
# [8.93600576]
# [-131.27309763]
# [-101.25715123]
# [301.79443485]
# [-80.97430652]
# [125.04457154]
# [-46.52727089]
# [301.79443485]
# [-160.62941529]
# [29.08710411]
# [-304.18292371]
# [19.96900922]
# [93.55570566]
# [-59.65374905]
# [-61.91073222]
# [-395.55347203]
# [-156.88411255]
# [61.79707015]
# [-142.82958627]
# [301.79443485]
# [-159.88151278]
# [-109.761356]
# [-22.64645279]
# [-105.83103467]
# [-54.65713744]
# [-395.55347203]
# [-395.55347203]
# [228.80694828]

# %%
print(np.mean(error.dot(error)))
# Out:
# 159489.7254169377

# %%
print(pred)
print(y_test)
# Out:
# [[ -98.82391381]
#  [  19.72216081]
#  [  78.13487224]
#  [  48.14641671]
#  [  78.13487224]
#  [ -20.82819591]
#  [ -10.05088031]
#  [  -1.0731688 ]
#  [-106.62772128]
#  [  41.56707078]
#  [  78.13487224]
#  [  78.13487224]
#  [ -34.41430689]
#  [  78.13487224]
#  [ -50.88793986]
#  [  22.61529338]
#  [ -18.615637  ]
#  [ -36.517041  ]
#  [ -72.9741551 ]
#  [  57.60432061]
#  [ -74.20465542]
#  [  31.42927784]
#  [ -59.74584221]
#  [  78.13487224]
#  [  78.13487224]
#  [  16.15800955]
#  [  11.62320831]
#  [ -30.9746346 ]
#  [  69.15854153]
#  [  19.77354541]
#  [  48.32177451]
#  [ -85.59360115]
#  [ -43.11201152]
#  [ -44.37935923]
#  [ -54.67819936]
#  [  26.90480397]
#  [  78.13487224]
#  [  78.13487224]
#  [ -22.95617885]
#  [  16.24105429]
#  [ -46.22127879]
#  [   4.19208682]
#  [ -26.87543909]
#  [  33.05907476]
#  [  78.13487224]
#  [ -72.9741551 ]
#  [  27.46110155]
#  [ -61.72591422]
#  [   3.66511319]
#  [ -34.73726946]
#  [  78.13487224]
#  [  68.46059217]
#  [  16.60234815]
#  [  14.18618324]
#  [  11.97339665]
#  [-107.89893195]
#  [  78.13487224]
#  [  19.04703101]
#  [ -14.56999794]
#  [  78.13487224]
#  [  -7.46881237]
#  [  38.59405655]
#  [  -7.7793143 ]
#  [   2.3296437 ]
#  [ -70.37702004]
#  [   7.72760102]
#  [  28.52959457]
#  [  33.70895286]
#  [ -84.91829452]
#  [ -10.32500439]
#  [ -99.31448624]
#  [ -69.55822094]
#  [ -64.43502299]
#  [  42.13755247]
#  [   4.61695146]
#  [ -76.54495278]
#  [  36.61845355]
#  [  78.13487224]
#  [  -4.34983946]
#  [  31.48076363]
#  [ -47.77608629]
#  [  78.13487224]
#  [ -72.9741551 ]
#  [  42.51708479]
#  [  78.13487224]
#  [  32.83363439]
#  [ -46.27893878]
#  [  42.40046477]
#  [  76.77224062]
#  [ -34.00116902]
#  [  78.13487224]
#  [ -98.26825324]
#  [  58.03556277]
#  [  -8.85168566]
#  [  78.13487224]
#  [-133.43623778]
#  [  37.00715205]
#  [ -63.09509925]
#  [ -41.06764369]
#  [  47.86307963]
#  [ -56.98513211]
#  [  21.61469849]
#  [ -72.9741551 ]
#  [ -83.02989976]
#  [  47.49079844]
#  [ -30.09893017]
#  [  78.13487224]
#  [ -77.46858837]
#  [-130.62985718]
#  [ -14.98794006]
#  [  64.91081109]
#  [   5.45055716]
#  [ -72.9741551 ]
#  [ -72.9741551 ]
#  [  69.28884678]]
# [56.53013699 40.36894977 61.65730594  0.         31.75159817 56.1803653
#  25.94954338 50.23242009 21.93858447 71.79109589 34.41940639 23.35251142
#   0.         20.89360731 21.05479452 34.66826484 15.48515982 59.11347032
#  49.57671233 29.76369863 53.22694064 36.2609589  17.5109589  52.85251142
#   0.         59.58219178 42.60525114 71.72968037 37.32945205 56.1326484
#  50.62990868 22.05753425 34.66826484 48.57123288 45.23789954 78.56575342
#   0.         30.61894977 42.39908676 36.5739726  25.87990868 76.04931507
#  27.98515982 38.03013699 63.7609589  29.68584475 40.83881279 42.61894977
#  54.04931507 21.07123288 39.1326484  22.14634703 23.06575342 53.27191781
#  26.50821918 28.47694064 17.34429224 22.53287671 26.41278539 19.95776256
#  18.96050228 32.90182648  0.         37.52465753 63.10799087 56.39360731
#  40.67214612 25.50547945 35.19680365 29.91940639 40.09155251  0.
#  77.57123288 57.22694064 17.49611872  0.         24.40456621 23.62990868
#  41.02739726 62.68584475 54.16552511  0.          0.         32.8716895
#  46.61073059 38.34155251 69.37990868 30.00273973 34.25273973 26.61073059
#  24.05205479 25.70502283 24.92762557 45.09155251 21.08219178 62.40456621
#  21.0630137  28.88538813 21.49063927 43.65182648 68.06849315 27.09429224
#  41.86073059 27.74611872 26.58881279 27.93858447 76.03287671 46.03287671
#  60.43584475 18.19680365 46.88812785 20.54109589 34.28561644 28.82945205
#  27.48789954]
